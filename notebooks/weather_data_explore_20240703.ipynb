# %% [markdown]
# # Exploring New Weather Data
# ### Andrew Attilio
# ### July 3, 2024
#
# I acquired weather data that appears useful:
# https://www.kaggle.com/datasets/guillemservera/global-daily-climate-data
#
# We want to create a feature for forecasting that incorporates temperature
# data, as we assume this affects the spread of diseases.

# %%
import pandas as pd

cities_df = pd.read_csv('../weather_data/cities.csv')
cities_df.head()
# Out:
#   station_id   city_name      country       state iso2 iso3   latitude  \
# 0      41515    Asadabad  Afghanistan       Kunar   AF  AFG  34.866000
# 1      38954    Fayzabad  Afghanistan  Badakhshan   AF  AFG  37.129761
# 2      41560   Jalalabad  Afghanistan   Nangarhar   AF  AFG  34.441527
# 3      38947      Kunduz  Afghanistan      Kunduz   AF  AFG  36.727951
# 4      38987  Qala i Naw  Afghanistan     Badghis   AF  AFG  34.983000
#
#    longitude
# 0  71.150005
# 1  70.579247
# 2  70.436103
# 3  68.872530
# 4  63.133300

# %%
cities_df = cities_df.loc[cities_df['iso2'] == 'US']
cities_df.head()
# Out:
#      station_id  city_name                   country     state iso2 iso3  \
# 1138      72518     Albany  United States of America  New York   US  USA
# 1139      72406  Annapolis  United States of America  Maryland   US  USA
# 1140      72219    Atlanta  United States of America   Georgia   US  USA
# 1141      74389    Augusta  United States of America     Maine   US  USA
# 1142      72254     Austin  United States of America     Texas   US  USA
#
#        latitude  longitude
# 1138  42.670017 -73.819949
# 1139  38.978330 -76.492499
# 1140  33.830014 -84.399949
# 1141  44.310563 -69.779989
# 1142  30.266950 -97.742778

# %%
cities_df.nunique()
# Out:
# station_id    49
# city_name     49
# country        1
# state         49
# iso2           1
# iso3           1
# latitude      49
# longitude     49
# dtype: int64

# %% [markdown]
# Our existing data uses location codes. We need a mapping of these location
# codes with the location names in the weather data.

# %%
# Read location data.
locations = pd.read_csv("../datasets/locations.csv").iloc[1:]  # skip first row

# Map location codes to state names.
location_to_state = dict(zip(locations["location"], 
                             locations["location_name"]))

location_to_state
# Out:
# {'01': 'Alabama',
#  '02': 'Alaska',
#  '04': 'Arizona',
#  '05': 'Arkansas',
#  '06': 'California',
#  '08': 'Colorado',
#  '09': 'Connecticut',
#  '10': 'Delaware',
#  '11': 'District of Columbia',
#  '12': 'Florida',
#  '13': 'Georgia',
#  '15': 'Hawaii',
#  '16': 'Idaho',
#  '17': 'Illinois',
#  '18': 'Indiana',
#  '19': 'Iowa',
#  '20': 'Kansas',
#  '21': 'Kentucky',
#  '22': 'Louisiana',
#  '23': 'Maine',
#  '24': 'Maryland',
#  '25': 'Massachusetts',
#  '26': 'Michigan',
#  '27': 'Minnesota',
#  '28': 'Mississippi',
#  '29': 'Missouri',
#  '30': 'Montana',
#  '31': 'Nebraska',
#  '32': 'Nevada',
#  '33': 'New Hampshire',
#  '34': 'New Jersey',
#  '35': 'New Mexico',
#  '36': 'New York',
#  '37': 'North Carolina',
#  '38': 'North Dakota',
#  '39': 'Ohio',
#  '40': 'Oklahoma',
#  '41': 'Oregon',
#  '42': 'Pennsylvania',
#  '44': 'Rhode Island',
#  '45': 'South Carolina',
#  '46': 'South Dakota',
#  '47': 'Tennessee',
#  '48': 'Texas',
#  '49': 'Utah',
#  '50': 'Vermont',
#  '51': 'Virginia',
#  '53': 'Washington',
#  '54': 'West Virginia',
#  '55': 'Wisconsin',
#  '56': 'Wyoming',
#  '72': 'Puerto Rico'}

# %% [markdown]
# Let's explore what the weather data has to offer. We want to predict the
# weather for a given day, so we can look at historical data and incorporate
# the current year's trend.

# %%
daily_weather = pd.read_parquet('../weather_data/daily_weather.parquet')

# %%
daily_weather.head()
# Out:
#   station_id city_name       date  season  avg_temp_c  min_temp_c  max_temp_c  \
# 0      41515  Asadabad 1957-07-01  Summer        27.0        21.1        35.6
# 1      41515  Asadabad 1957-07-02  Summer        22.8        18.9        32.2
# 2      41515  Asadabad 1957-07-03  Summer        24.3        16.7        35.6
# 3      41515  Asadabad 1957-07-04  Summer        26.6        16.1        37.8
# 4      41515  Asadabad 1957-07-05  Summer        30.8        20.0        41.7
#
#    precipitation_mm  snow_depth_mm  avg_wind_dir_deg  avg_wind_speed_kmh  \
# 0               0.0            NaN               NaN                 NaN
# 1               0.0            NaN               NaN                 NaN
# 2               1.0            NaN               NaN                 NaN
# 3               4.1            NaN               NaN                 NaN
# 4               0.0            NaN               NaN                 NaN
#
#    peak_wind_gust_kmh  avg_sea_level_pres_hpa  sunshine_total_min
# 0                 NaN                     NaN                 NaN
# 1                 NaN                     NaN                 NaN
# 2                 NaN                     NaN                 NaN
# 3                 NaN                     NaN                 NaN
# 4                 NaN                     NaN                 NaN

# %%
us_station_ids = cities_df['station_id'].unique()

# %%
daily_weather = daily_weather.loc[daily_weather['station_id'].isin(us_station_ids)]

# %%
daily_weather.head()
# Out:
#   station_id city_name       date  season  avg_temp_c  min_temp_c  max_temp_c  \
# 0      72518    Albany 1938-06-01  Summer         NaN         8.3        26.7
# 1      72518    Albany 1938-06-02  Summer         NaN         9.4        26.1
# 2      72518    Albany 1938-06-03  Summer         NaN        13.9        23.3
# 3      72518    Albany 1938-06-04  Summer         NaN         9.4        25.0
# 4      72518    Albany 1938-06-05  Summer         NaN        13.3        22.2
#
#    precipitation_mm  snow_depth_mm  avg_wind_dir_deg  avg_wind_speed_kmh  \
# 0               0.0            0.0               NaN                 NaN
# 1               5.1            0.0               NaN                 NaN
# 2               4.1            0.0               NaN                 NaN
# 3               0.0            0.0               NaN                 NaN
# 4               0.0            0.0               NaN                 NaN
#
#    peak_wind_gust_kmh  avg_sea_level_pres_hpa  sunshine_total_min
# 0                 NaN                     NaN                 NaN
# 1                 NaN                     NaN                 NaN
# 2                 NaN                     NaN                 NaN
# 3                 NaN                     NaN                 NaN
# 4                 NaN                     NaN                 NaN

# %%
daily_weather = daily_weather.loc[daily_weather['date'] >= pd.to_datetime
('2000-01-01')]

# %%
daily_weather.head()
# Out:
#       station_id city_name       date  season  avg_temp_c  min_temp_c  \
# 22493      72518    Albany 2000-01-01  Winter         1.0        -4.4
# 22494      72518    Albany 2000-01-02  Winter         6.0        -1.7
# 22495      72518    Albany 2000-01-03  Winter         8.9         0.6
# 22496      72518    Albany 2000-01-04  Winter         7.6         0.6
# 22497      72518    Albany 2000-01-05  Winter        -2.5        -8.3
#
#        max_temp_c  precipitation_mm  snow_depth_mm  avg_wind_dir_deg  \
# 22493         7.2               0.0            0.0             172.0
# 22494        11.7               0.5            0.0               NaN
# 22495        13.3               2.3            0.0               NaN
# 22496        15.6              16.5            0.0               NaN
# 22497         3.3               0.0            0.0             305.0
#
#        avg_wind_speed_kmh  peak_wind_gust_kmh  avg_sea_level_pres_hpa  \
# 22493                13.7                 NaN                  1022.2
# 22494                15.5                 NaN                  1017.6
# 22495                14.8                 NaN                     NaN
# 22496                19.4                 NaN                  1006.2
# 22497                25.9                 NaN                  1020.1
#
#        sunshine_total_min
# 22493                 NaN
# 22494                 NaN
# 22495                 NaN
# 22496                 NaN
# 22497                 NaN

# %% [markdown]
# For each station_id (which we can map to our other
# data by station_id -> location_name -> location_code), we will average the
# past ~20 years of temp data, and then incorporate this year's trend.
#
# To get a week's average temperature, we will average the avg_temp_c over the
#  7 days of that week.
#
# For a given prediction/row, we will include the previous week's temperature
# as a feature, as this may have a bigger effect on current hospitalizations.

# %%
daily_weather['year'] = daily_weather['date'].dt.year

# %%
daily_weather['yearly_avg_temp'] = (daily_weather.groupby('year')
                                     ['avg_temp_c']
                                   .transform
                         ('mean'))

# %%
daily_weather.drop(columns=['snow_depth_mm', 'avg_wind_dir_deg', 
                            'avg_wind_speed_kmh', 'peak_wind_gust_kmh', 
                            'avg_sea_level_pres_hpa'], 
                   inplace=True)
daily_weather.head()
# Out:
#       station_id city_name       date  season  avg_temp_c  min_temp_c  \
# 22493      72518    Albany 2000-01-01  Winter         1.0        -4.4
# 22494      72518    Albany 2000-01-02  Winter         6.0        -1.7
# 22495      72518    Albany 2000-01-03  Winter         8.9         0.6
# 22496      72518    Albany 2000-01-04  Winter         7.6         0.6
# 22497      72518    Albany 2000-01-05  Winter        -2.5        -8.3
#
#        max_temp_c  precipitation_mm  sunshine_total_min  year  yearly_avg_temp
# 22493         7.2               0.0                 NaN  2000        12.939173
# 22494        11.7               0.5                 NaN  2000        12.939173
# 22495        13.3               2.3                 NaN  2000        12.939173
# 22496        15.6              16.5                 NaN  2000        12.939173
# 22497         3.3               0.0                 NaN  2000        12.939173

# %%
daily_weather.drop(columns=['sunshine_total_min'])
# Out:
#       station_id   city_name       date  season  avg_temp_c  min_temp_c  \
# 22493      72518      Albany 2000-01-01  Winter         1.0        -4.4
# 22494      72518      Albany 2000-01-02  Winter         6.0        -1.7
# 22495      72518      Albany 2000-01-03  Winter         8.9         0.6
# 22496      72518      Albany 2000-01-04  Winter         7.6         0.6
# 22497      72518      Albany 2000-01-05  Winter        -2.5        -8.3
# ...          ...         ...        ...     ...         ...         ...
# 31776      72405  Washington 2023-09-01  Autumn        22.2        18.5
# 31777      72405  Washington 2023-09-02  Autumn        24.3        20.2
# 31778      72405  Washington 2023-09-03  Autumn        25.4        21.5
# 31779      72405  Washington 2023-09-04  Autumn        25.8        22.1
# 31780      72405  Washington 2023-09-05  Autumn        25.5        22.6
#
#        max_temp_c  precipitation_mm  year  yearly_avg_temp
# 22493         7.2               0.0  2000        12.939173
# 22494        11.7               0.5  2000        12.939173
# 22495        13.3               2.3  2000        12.939173
# 22496        15.6              16.5  2000        12.939173
# 22497         3.3               0.0  2000        12.939173
# ...           ...               ...   ...              ...
# 31776        25.3               NaN  2023        14.875153
# 31777        28.6               NaN  2023        14.875153
# 31778        29.5               NaN  2023        14.875153
# 31779        30.1               NaN  2023        14.875153
# 31780        29.0               NaN  2023        14.875153
#
# [422514 rows x 10 columns]

# %%
daily_weather.to_parquet('../weather_data/daily_weather_cleaned_20240703'
                         '.parquet')

# %%
df = pd.read_csv('../datasets/forest_features_20240702.csv')
df
# Out:
#             date  1wk_WIS  1_week_roc  is_wis_above_avg  1st_deriv_stencil  \
# 0     2023-10-28    19.51    0.320000                 0           7.333333
# 1     2023-11-04     6.51    0.181818                 0           4.166667
# 2     2023-11-11    45.84    0.205128                 0          27.750000
# 3     2023-11-18    11.54    0.851064                 0          16.416667
# 4     2023-11-25    37.36   -0.034483                 0          25.750000
# ...          ...      ...         ...               ...                ...
# 1113  2024-03-02     7.56   -0.173077                 0          -1.000000
# 1114  2024-03-09    13.41    0.209302                 0          14.166667
# 1115  2024-03-16     2.61    0.230769                 0          -1.750000
# 1116  2024-03-23     2.18   -0.218750                 0          -8.000000
# 1117  2024-03-30     3.87   -0.040000                 0          -2.000000
#
#       week_of_year  moving_avg_WIS  lagged_1wk_WIS  loc_code  \
# 0               43       13.273333           13.51        18
# 1               44       13.176667           19.51        18
# 2               45       23.953333            6.51        18
# 3               46       21.296667           45.84        18
# 4               47       31.580000           11.54        18
# ...            ...             ...             ...       ...
# 1113             9        4.150000            1.44        72
# 1114            10        7.470000            7.56        72
# 1115            11        7.860000           13.41        72
# 1116            12        6.066667            2.61        72
# 1117            13        2.886667            2.18        72
#
#       holiday_last_week  population  pred_hosp  actual_hosp  \
# 0                     0     6785528  14.324939         39.0
# 1                     0     6785528  14.324939         47.0
# 2                     0     6785528  38.088067         87.0
# 3                     1     6785528  38.088067         84.0
# 4                     0     6785528  84.159595        138.0
# ...                 ...         ...        ...          ...
# 1113                  1     3285874  41.556136         52.0
# 1114                  0     3285874  41.556136         64.0
# 1115                  0     3285874  42.345551         50.0
# 1116                  0     3285874  44.852743         48.0
# 1117                  0     3285874  44.852743         39.0
#
#       is_prediction_over
# 0                  False
# 1                  False
# 2                  False
# 3                  False
# 4                  False
# ...                  ...
# 1113               False
# 1114               False
# 1115               False
# 1116               False
# 1117                True
#
# [1118 rows x 14 columns]
