# %%
import numpy as np
import pandas as pd
from os import listdir
from os.path import isfile, join
from sys import path
import matplotlib.pyplot as plt
import pymmwr as pm
from datetime import datetime
from datetime import date
from datetime import timedelta
import seaborn as sns

# %%
'''Import locations'''

locations = pd.read_csv('./locations.csv',skiprows=0) 
locations = locations.drop([0]) #skip first row (national ID)
print("Number of Locations:", len(locations))
locations.head()
# Out:
# Number of Locations: 52
#   abbreviation location location_name  population  Unnamed: 4  count_rate1  \
# 1           AL       01       Alabama     5063778         NaN           51
# 2           AK       02        Alaska      711426         NaN            7
# 3           AZ       04       Arizona     7341018         NaN           73
# 4           AR       05      Arkansas     3041878         NaN           30
# 5           CA       06    California    38886551         NaN          389
#
#    count_rate2  count_rate2p5  count_rate3  count_rate4  count_rate5
# 1          101            127          152          203          253
# 2           14             18           21           28           36
# 3          147            184          220          294          367
# 4           61             76           91          122          152
# 5          778            972         1167         1555         1944

# %%
'''Extract hospitalization data'''

actual_data = pd.read_csv('./COVID-19_Reported_Patient_Impact_and_Hospital_Capacity_by_State_Timeseries__RAW_.csv') 
actual_data = actual_data[['date','state','previous_day_admission_influenza_confirmed']].sort_values(['state','date'])
actual_data['date'] = pd.to_datetime(actual_data['date'])
actual_data.head()
# Out:
#             date state  previous_day_admission_influenza_confirmed
# 33828 2020-03-23    AK                                         NaN
# 28607 2020-03-24    AK                                         NaN
# 34678 2020-03-25    AK                                         NaN
# 32325 2020-03-26    AK                                         NaN
# 26758 2020-03-27    AK                                         NaN

# %%
'''Map location numbers to state abbreviations'''

location_to_state = {}
for index, row in locations.iterrows():
    location_number = row['location']
    abbreviation = row['abbreviation']
    location_to_state.update({location_number: abbreviation})
print(location_to_state)
# Out:
# {'01': 'AL', '02': 'AK', '04': 'AZ', '05': 'AR', '06': 'CA', '08': 'CO', '09': 'CT', '10': 'DE', '11': 'DC', '12': 'FL', '13': 'GA', '15': 'HI', '16': 'ID', '17': 'IL', '18': 'IN', '19': 'IA', '20': 'KS', '21': 'KY', '22': 'LA', '23': 'ME', '24': 'MD', '25': 'MA', '26': 'MI', '27': 'MN', '28': 'MS', '29': 'MO', '30': 'MT', '31': 'NE', '32': 'NV', '33': 'NH', '34': 'NJ', '35': 'NM', '36': 'NY', '37': 'NC', '38': 'ND', '39': 'OH', '40': 'OK', '41': 'OR', '42': 'PA', '44': 'RI', '45': 'SC', '46': 'SD', '47': 'TN', '48': 'TX', '49': 'UT', '50': 'VT', '51': 'VA', '53': 'WA', '54': 'WV', '55': 'WI', '56': 'WY', '72': 'PR'}

# %%
'''Testing. Get a single state's actual data.'''

NY_actual_data = pd.DataFrame(actual_data[actual_data['state'] == 'NY'])
NY_actual_data
daily_count = NY_actual_data.loc[NY_actual_data['date'] == '2023-05-13'].values[0, 2]
daily_count
# Out:
# 7.0

# %%
'''Convert the forecast data files into a dataframe'''

from os import listdir
from os.path import isfile, join

forecast_path = './LosAlamos_NAU-CModel_Flu/'
forecast_files = [file for file in listdir(forecast_path) if isfile(join(forecast_path, file))]
forecast_files.sort()

dataframes = []
for file in forecast_files:
    df = pd.read_csv(forecast_path + file)
    df['target_end_date'] = pd.to_datetime(df['target_end_date'])
    dataframes.append(df)

all_forecasts = pd.concat(dataframes)
all_forecasts
# Out:
#      reference_date                   target  horizon target_end_date  \
# 0        2023-10-21          wk inc flu hosp       -1      2023-10-14
# 1        2023-10-21          wk inc flu hosp       -1      2023-10-14
# 2        2023-10-21          wk inc flu hosp       -1      2023-10-14
# 3        2023-10-21          wk inc flu hosp       -1      2023-10-14
# 4        2023-10-21          wk inc flu hosp       -1      2023-10-14
# ...             ...                      ...      ...             ...
# 5931     2024-05-04  wk flu hosp rate change        3      2024-05-25
# 5932     2024-05-04  wk flu hosp rate change        3      2024-05-25
# 5933     2024-05-04  wk flu hosp rate change        3      2024-05-25
# 5934     2024-05-04  wk flu hosp rate change        3      2024-05-25
# 5935     2024-05-04  wk flu hosp rate change        3      2024-05-25
#
#      location output_type  output_type_id  value
# 0          11    quantile            0.01    0.0
# 1          11    quantile           0.025    0.0
# 2          11    quantile            0.05    0.0
# 3          11    quantile             0.1    0.0
# 4          11    quantile            0.15    0.0
# ...       ...         ...             ...    ...
# 5931       US         pmf          stable    1.0
# 5932       US         pmf        increase    0.0
# 5933       US         pmf  large_increase    0.0
# 5934       US         pmf        decrease    0.0
# 5935       US         pmf  large_decrease    0.0
#
# [170436 rows x 8 columns]

# %%
'''Testing. Get a single state's forecast data.'''

MI_forecast_data = all_forecasts[all_forecasts['location'] == '26']
MI_forecast_data = MI_forecast_data[MI_forecast_data['output_type'] == 'quantile']
MI_forecast_data['output_type_id'] = MI_forecast_data['output_type_id'].astype(float)
MI_forecast_data.to_csv('./mi-data-test.csv')

print(all(isinstance(x, float) for x in MI_forecast_data['value']))

print(all(isinstance(x, float) for x in MI_forecast_data['output_type_id']))
# Out:
# True
# True

# %%
'''Define the Interval Score and Weighted Interval Score functions'''
'''https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7880475/'''

def IS(alpha, predL, predU):
    
    return lambda y: (predU - predL) + 2/alpha*(y < predL)*(predL - y) + 2/alpha*(y > predU)*(y-predU)

def WIS(y_obs, qtlMark, predQTL):
    
    is_well_defined = np.mod(len(qtlMark), 2) != 0
    
    NcentralizedQT = (len(qtlMark)-1)//2 + 1
    
    alpha_list = np.zeros(NcentralizedQT)
    weight_list = np.zeros(NcentralizedQT)
    
    for i in range(NcentralizedQT):  
        is_well_defined = is_well_defined & (np.abs(-1.0 + qtlMark[i] + qtlMark[-1-i]) < 1e-8)
        alpha_list[i] = 1 - (qtlMark[-1-i] - qtlMark[i])
        weight_list[i] = alpha_list[i]/2
        
    if is_well_defined:
        #print(alpha_list)
        #print(qtlMark)
        #print(NcentralizedQT)
        
        output = 1.0/2 * np.abs(y_obs - predQTL[NcentralizedQT - 1])
        
        for i in range(NcentralizedQT - 1):
            output += weight_list[i] * IS(alpha_list[i], predQTL[i], predQTL[-1 - i])(y_obs)
            #print(alpha_list[i], predQTL[i],predQTL[-1-i])
            
        return output/(NcentralizedQT - 1/2)
    
    else:
        print('Check the quantile marks: either no median defined, or not in symmetric central QTL form.')

# %%
'''Testing to see if all states/locations are represented in our forecast data files. '''
test_data = pd.read_csv('./LosAlamos_NAU-CModel_Flu/2023-10-21-LosAlamos_NAU-CModel_Flu.csv')
unique_states = len(test_data['location'].unique())
unique_states
# Out:
# 53

# %%
def get_target_dates_list(forecast_df):
    return forecast_df['target_end_date'].unique()


def get_state_actual_data(state_code):
    state_abbrev = location_to_state[str(state_code).zfill(2)]
    return actual_data[actual_data['state'] == state_abbrev]


def one_state_one_week_WIS_scores(forecast_df, state_code):
    state_code = str(state_code).zfill(2)
    quantiles = np.zeros((23,4))
    wis = np.zeros(4)

    state_actual_data = get_state_actual_data(state_code)

    target_dates = get_target_dates_list(forecast_df)

    for n_week_ahead in range(4):
        target_date = target_dates[n_week_ahead]


        # Sum the daily reported cases to find the weekly observation.
        observation = 0
        for i in range(7):
            target_date = str(date.fromisoformat(target_date) + timedelta(days=-i))
            daily_count = state_actual_data.loc[state_actual_data['date'] == target_date].values[0, 2]
            observation += daily_count

        df_state = forecast_df[forecast_df['location'].to_numpy() == state_code]
        df_state_forecast = df_state[df_state['target_end_date'] == target_dates[n_week_ahead]]
        quantiles = df_state_forecast['output_type_id'].astype(float).to_numpy()
        predictions = df_state_forecast['value'].astype(float).to_numpy()
        
        try:
            wis[n_week_ahead] = np.round(
                                np.sum(np.nan_to_num(
                                    WIS(observation, 
                                        quantiles, 
                                        predictions))),
                                        2)
        except:
            # if an error occurs, print the corresponding data
            print("An error occured. Output will include a row of 0's.")
            print(df_state_forecast)
            print(quantiles)
            print(predictions)

    # Send scores to csv
    one_week_scores = {'state_code': state_code, 'state_abbrev': location_to_state[state_code], 'date': target_dates[0], '1wk_WIS': wis[0],'2wk_WIS': wis[1], '3wk_WIS': wis[2], '4wk_WIS': wis[3]}

    return one_week_scores


def one_state_all_scores(state_code):
    state_code = str(state_code).zfill(2)
    
    state_df = pd.DataFrame(columns=[])

    forecast_path = './LosAlamos_NAU-CModel_Flu/'
    forecast_files = [file for file in listdir(forecast_path) if isfile(join(forecast_path, file))]
    forecast_files.sort()

    for file in forecast_files:
        all_forecast_data = pd.read_csv(forecast_path + file)
        all_forecast_data = all_forecast_data[all_forecast_data['output_type'] == 'quantile']

        weekly_scores = one_state_one_week_WIS_scores(all_forecast_data, state_code)
        state_df = pd.concat([state_df, pd.DataFrame([weekly_scores])], ignore_index=True)
    
    # Export to CSV
    state_csv_path = './mcmc_accuracy_results/' + location_to_state[state_code] + '.csv'
    state_df.to_csv(state_csv_path)

# %%
''' Testing '''

forecast_path = './LosAlamos_NAU-CModel_Flu/2023-10-21-LosAlamos_NAU-CModel_Flu.csv'
all_forecast_data = pd.read_csv(forecast_path)
all_forecast_data = all_forecast_data[all_forecast_data['output_type'] == 'quantile']
AZ_forecast_data = all_forecast_data[all_forecast_data['location'] == '04']

# Check if all values are floats. 
all(isinstance(x, float) for x in AZ_forecast_data['value'])
# Out:
# True

# %%
''' Testing the one state function '''

one_state_one_week_WIS_scores(all_forecast_data, 4)
# Out:
# Target Dates: ['2023-10-14' '2023-10-21' '2023-10-28' '2023-11-04' '2023-11-11']
# Observation: 24.0
# Observation: 34.0
# Observation: 35.0
# Observation: 46.0
#
# WIS: [13.96 20.47 26.59 32.46]
# {'state_code': '04',
#  'state_abbrev': 'AZ',
#  'date': '2023-10-14',
#  '1wk_WIS': 13.96,
#  '2wk_WIS': 20.47,
#  '3wk_WIS': 26.59,
#  '4wk_WIS': 32.46}

# %%
one_state_all_scores('04')
# Out:
# Target Dates: ['2023-10-14' '2023-10-21' '2023-10-28' '2023-11-04' '2023-11-11']
# Observation: 24.0
# Observation: 34.0
# Observation: 35.0
# Observation: 46.0
#
# WIS: [13.96 20.47 26.59 32.46]
# Target Dates: ['2023-10-21' '2023-10-28' '2023-11-04' '2023-11-11' '2023-11-18']
# Observation: 34.0
# Observation: 35.0
# Observation: 46.0
# Observation: 85.0
#
# WIS: [11.13  7.98 17.58 64.31]
# Target Dates: ['2023-10-28' '2023-11-04' '2023-11-11' '2023-11-18' '2023-11-25']
# Observation: 35.0
# Observation: 46.0
# Observation: 85.0
# Observation: 145.0
#
# WIS: [ 12.13  18.74  56.58 124.31]
# Target Dates: ['2023-11-11' '2023-11-18' '2023-11-25' '2023-12-02']
# Observation: 85.0
# Observation: 145.0
# Observation: 176.0
# Observation: 232.0
#
# WIS: [ 28.2   79.27  98.32 141.61]
# Target Dates: ['2023-11-18' '2023-11-25' '2023-12-02' '2023-12-09']
# Observation: 145.0
# Observation: 176.0
# Observation: 232.0
# Observation: 323.0
#
# WIS: [ 88.2  110.27 154.32 232.61]
# Target Dates: ['2023-11-25' '2023-12-02' '2023-12-09' '2023-12-16']
# Observation: 176.0
# Observation: 232.0
# Observation: 323.0
# Observation: 456.0
#
# WIS: [ 34.62  51.55  89.54 158.12]
# Target Dates: ['2023-12-02' '2023-12-09' '2023-12-16' '2023-12-23']
# Observation: 232.0
# Observation: 323.0
# Observation: 456.0
# Observation: 722.0
#
# WIS: [ 14.08  23.61  50.7  191.4 ]
# Target Dates: ['2023-12-09' '2023-12-16' '2023-12-23' '2023-12-30']
# Observation: 323.0
# Observation: 456.0
# Observation: 722.0
# Observation: 898.0
#
# WIS: [ 36.13  81.89 119.06 333.32]
# Target Dates: ['2023-12-16' '2023-12-23' '2023-12-30' '2024-01-06']
# Observation: 456.0
# Observation: 722.0
# Observation: 898.0
# Observation: 946.0
#
# WIS: [ 22.45  40.76  58.83 261.04]
# Target Dates: ['2023-12-23' '2023-12-30' '2024-01-06' '2024-01-13']
# Observation: 722.0
# Observation: 898.0
# Observation: 946.0
# Observation: 862.0
#
# WIS: [ 77.31  55.19  95.74 482.76]
# Target Dates: ['2023-12-30' '2024-01-06' '2024-01-13' '2024-01-20']
# Observation: 898.0
# Observation: 946.0
# Observation: 862.0
# Observation: 740.0
#
# WIS: [ 190.05  532.57 1120.86 1872.3 ]
# Target Dates: ['2024-01-06' '2024-01-13' '2024-01-20' '2024-01-27']
# Observation: 946.0
# Observation: 862.0
# Observation: 740.0
# Observation: 622.0
#
# WIS: [ 545.17 1138.66 1888.5  2752.71]
# Target Dates: ['2024-01-13' '2024-01-20' '2024-01-27' '2024-02-03']
# Observation: 862.0
# Observation: 740.0
# Observation: 622.0
# Observation: 507.0
#
# WIS: [ 669.   1275.98 2005.39 2830.31]
# Target Dates: ['2024-01-20' '2024-01-27' '2024-02-03' '2024-02-10']
# Observation: 740.0
# Observation: 622.0
# Observation: 507.0
# Observation: 335.0
#
# WIS: [ 695.54 1198.3  1764.34 2431.39]
# Target Dates: ['2024-02-03' '2024-02-10' '2024-02-17' '2024-02-24']
# Observation: 507.0
# Observation: 335.0
# Observation: 272.0
# Observation: 212.0
#
# WIS: [ 17.94  89.52  94.83 102.97]
# Target Dates: ['2024-02-10' '2024-02-17' '2024-02-24' '2024-03-02']
# Observation: 335.0
# Observation: 272.0
# Observation: 212.0
# Observation: 191.0
#
# WIS: [29.82 31.02 39.63 21.69]
# Target Dates: ['2024-02-17' '2024-02-24' '2024-03-02' '2024-03-09']
# Observation: 272.0
# Observation: 212.0
# Observation: 191.0
# Observation: 148.0
#
# WIS: [20.47 11.22 21.07 16.33]
# Target Dates: ['2024-02-24' '2024-03-02' '2024-03-09' '2024-03-16']
# Observation: 212.0
# Observation: 191.0
# Observation: 148.0
# Observation: 159.0
#
# WIS: [24.63 37.07 29.43 59.78]
# Target Dates: ['2024-03-02' '2024-03-09' '2024-03-16' '2024-03-23']
# Observation: 191.0
# Observation: 148.0
# Observation: 159.0
# Observation: 118.0
#
# WIS: [29.62 20.65 47.75 30.57]
# Target Dates: ['2024-03-09' '2024-03-16' '2024-03-23' '2024-03-30']
# Observation: 148.0
# Observation: 159.0
# Observation: 118.0
# Observation: 104.0
#
# WIS: [ 8.17 28.78 17.44 20.23]
# Target Dates: ['2024-03-16' '2024-03-23' '2024-03-30' '2024-04-06']
# Observation: 159.0
# Observation: 118.0
# Observation: 104.0
# Observation: 106.0
#
# WIS: [38.5  21.62 24.63 39.4 ]
# Target Dates: ['2024-03-23' '2024-03-30' '2024-04-06' '2024-04-13']
# Observation: 118.0
# Observation: 104.0
# Observation: 106.0
# Observation: 91.0
#
# WIS: [16.47 20.9  34.37 31.74]
# Target Dates: ['2024-03-30' '2024-04-06' '2024-04-13' '2024-04-20']
# Observation: 104.0
# Observation: 106.0
# Observation: 91.0
# Observation: 77.0
#
# WIS: [ 8.52 22.55 21.67 20.03]
# Target Dates: ['2024-04-06' '2024-04-13' '2024-04-20' '2024-04-27']
# Observation: 106.0
# Observation: 91.0
# Observation: 77.0
# Observation: 92.0
#
# WIS: [27.35 26.82 22.13 46.69]

# %%
for state in location_to_state.keys():
    one_state_all_scores(state)
# Out:
# Target Dates: ['2023-10-14' '2023-10-21' '2023-10-28' '2023-11-04' '2023-11-11']
# Observation: 22.0
# Observation: 29.0
# Observation: 33.0
# Observation: 32.0
#
# WIS: [ 1.36  8.96 12.76 12.07]
# Target Dates: ['2023-10-21' '2023-10-28' '2023-11-04' '2023-11-11' '2023-11-18']
# Observation: 29.0
# Observation: 33.0
# Observation: 32.0
# Observation: 44.0
#
# WIS: [ 7.97  7.05  5.91 11.62]
# Target Dates: ['2023-10-28' '2023-11-04' '2023-11-11' '2023-11-18' '2023-11-25']
# Observation: 33.0
# Observation: 32.0
# Observation: 44.0
# Observation: 68.0
#
# WIS: [11.62  6.39 15.13 33.54]
# Target Dates: ['2023-11-11' '2023-11-18' '2023-11-25' '2023-12-02']
# Observation: 44.0
# Observation: 68.0
# Observation: 61.0
# Observation: 72.0
#
# WIS: [ 9.73 27.92 17.22 27.82]
# Target Dates: ['2023-11-18' '2023-11-25' '2023-12-02' '2023-12-09']
# Observation: 68.0
# Observation: 61.0
# Observation: 72.0
# Observation: 79.0
#
# WIS: [29.66 21.84 26.24 34.09]
# Target Dates: ['2023-11-25' '2023-12-02' '2023-12-09' '2023-12-16']
# Observation: 61.0
# Observation: 72.0
# Observation: 79.0
# Observation: 121.0
#
# WIS: [ 7.04 14.1  15.45 43.41]
# Target Dates: ['2023-12-02' '2023-12-09' '2023-12-16' '2023-12-23']
# Observation: 72.0
# Observation: 79.0
# Observation: 121.0
# Observation: 201.0
#
# WIS: [  9.57   7.18  32.32 100.84]
# Target Dates: ['2023-12-09' '2023-12-16' '2023-12-23' '2023-12-30']
# Observation: 79.0
# Observation: 121.0
# Observation: 201.0
# Observation: 235.0
#
# WIS: [16.41 10.89 13.41 14.08]
# Target Dates: ['2023-12-16' '2023-12-23' '2023-12-30' '2024-01-06']
# Observation: 121.0
# Observation: 201.0
# Observation: 235.0
# Observation: 321.0
#
# WIS: [ 6.75 16.52 10.69 21.56]
# Target Dates: ['2023-12-23' '2023-12-30' '2024-01-06' '2024-01-13']
# Observation: 201.0
# Observation: 235.0
# Observation: 321.0
# Observation: 272.0
#
# WIS: [39.69 37.27 73.34  7.57]
# Target Dates: ['2023-12-30' '2024-01-06' '2024-01-13' '2024-01-20']
# Observation: 235.0
# Observation: 321.0
# Observation: 272.0
# Observation: 217.0
#
# WIS: [ 16.57  13.97  98.11 246.31]
# Target Dates: ['2024-01-06' '2024-01-13' '2024-01-20' '2024-01-27']
# Observation: 321.0
# Observation: 272.0
# Observation: 217.0
# Observation: 165.0
#
# WIS: [ 20.64 138.11 304.85 498.17]
# Target Dates: ['2024-01-13' '2024-01-20' '2024-01-27' '2024-02-03']
# Observation: 272.0
# Observation: 217.0
# Observation: 165.0
# Observation: 139.0
#
# WIS: [147.54 314.69 510.46 706.02]
# Target Dates: ['2024-01-20' '2024-01-27' '2024-02-03' '2024-02-10']
# Observation: 217.0
# Observation: 165.0
# Observation: 139.0
# Observation: 121.0
#
# WIS: [185.34 332.62 486.25 647.48]
# Target Dates: ['2024-02-03' '2024-02-10' '2024-02-17' '2024-02-24']
# Observation: 139.0
# Observation: 121.0
# Observation: 111.0
# Observation: 97.0
#
# WIS: [10.21  9.62 14.93 12.6 ]
# Target Dates: ['2024-02-10' '2024-02-17' '2024-02-24' '2024-03-02']
# Observation: 121.0
# Observation: 111.0
# Observation: 97.0
# Observation: 86.0
#
# WIS: [18.9  28.18 32.36 37.05]
# Target Dates: ['2024-02-17' '2024-02-24' '2024-03-02' '2024-03-09']
# Observation: 111.0
# Observation: 97.0
# Observation: 86.0
# Observation: 77.0
#
# WIS: [20.43 27.47 29.85 39.24]
# Target Dates: ['2024-02-24' '2024-03-02' '2024-03-09' '2024-03-16']
# Observation: 97.0
# Observation: 86.0
# Observation: 77.0
# Observation: 80.0
#
# WIS: [22.46 23.79 26.1  38.11]
# Target Dates: ['2024-03-02' '2024-03-09' '2024-03-16' '2024-03-23']
# Observation: 86.0
# Observation: 77.0
# Observation: 80.0
# Observation: 72.0
#
# WIS: [17.36 19.94 33.24 39.28]
# Target Dates: ['2024-03-09' '2024-03-16' '2024-03-23' '2024-03-30']
# Observation: 77.0
# Observation: 80.0
# Observation: 72.0
# Observation: 71.0
#
# WIS: [12.18 22.32 25.24 38.28]
# Target Dates: ['2024-03-16' '2024-03-23' '2024-03-30' '2024-04-06']
# Observation: 80.0
# Observation: 72.0
# Observation: 71.0
# Observation: 51.0
#
# WIS: [21.7  15.72 28.46 15.61]
# Target Dates: ['2024-03-23' '2024-03-30' '2024-04-06' '2024-04-13']
# Observation: 72.0
# Observation: 71.0
# Observation: 51.0
# Observation: 33.0
#
# WIS: [12.36 18.98  9.55  5.76]
# Target Dates: ['2024-03-30' '2024-04-06' '2024-04-13' '2024-04-20']
# Observation: 71.0
# Observation: 51.0
# Observation: 33.0
# Observation: 27.0
#
# WIS: [11.88  6.68  3.56  2.89]
# Target Dates: ['2024-04-06' '2024-04-13' '2024-04-20' '2024-04-27']
# Observation: 51.0
# Observation: 33.0
# Observation: 27.0
# Observation: 20.0
#
# WIS: [4.15 2.76 4.05 3.06]
# Target Dates: ['2023-10-14' '2023-10-21' '2023-10-28' '2023-11-04' '2023-11-11']
# Observation: 9.0
# Observation: 23.0
# Observation: 27.0
# Observation: 33.0
#
# WIS: [ 3.27 16.7  19.01 23.04]
# Target Dates: ['2023-10-21' '2023-10-28' '2023-11-04' '2023-11-11' '2023-11-18']
# Observation: 23.0
# Observation: 27.0
# Observation: 33.0
# Observation: 33.0
#
# WIS: [6.83 7.34 9.76 4.94]
# Target Dates: ['2023-10-28' '2023-11-04' '2023-11-11' '2023-11-18' '2023-11-25']
# Observation: 27.0
# Observation: 33.0
# Observation: 33.0
# Observation: 24.0
#
# WIS: [10.64 12.8   9.76  2.99]
# Target Dates: ['2023-11-11' '2023-11-18' '2023-11-25' '2023-12-02']
# Observation: 33.0
# Observation: 24.0
# Observation: 23.0
# Observation: 15.0
#
# WIS: [ 3.46 22.17 36.34 62.49]
# Target Dates: ['2023-11-18' '2023-11-25' '2023-12-02' '2023-12-09']
# Observation: 24.0
# Observation: 23.0
# Observation: 15.0
# Observation: 12.0
#
# WIS: [11.47 23.17 44.34 65.49]
# Target Dates: ['2023-11-25' '2023-12-02' '2023-12-09' '2023-12-16']
# Observation: 23.0
# Observation: 15.0
# Observation: 12.0
# Observation: 6.0
#
# WIS: [26.55 48.48 67.75 94.66]
# Target Dates: ['2023-12-02' '2023-12-09' '2023-12-16' '2023-12-23']
# Observation: 15.0
# Observation: 12.0
# Observation: 6.0
# Observation: 6.0
#
# WIS: [22.39 34.95 50.51 61.87]
# Target Dates: ['2023-12-09' '2023-12-16' '2023-12-23' '2023-12-30']
# Observation: 12.0
# Observation: 6.0
# Observation: 6.0
# Observation: 6.0
#
# WIS: [1.32 2.21 1.79 1.88]
# Target Dates: ['2023-12-16' '2023-12-23' '2023-12-30' '2024-01-06']
# Observation: 6.0
# Observation: 6.0
# Observation: 6.0
# Observation: 3.0
#
# WIS: [1.23 2.35 3.75 1.74]
# Target Dates: ['2023-12-23' '2023-12-30' '2024-01-06' '2024-01-13']
# Observation: 6.0
# Observation: 6.0
# Observation: 3.0
# Observation: 6.0
#
# WIS: [0.88 4.36 0.62 3.92]
# Target Dates: ['2023-12-30' '2024-01-06' '2024-01-13' '2024-01-20']
# Observation: 6.0
# Observation: 3.0
# Observation: 6.0
# Observation: 9.0
#
# WIS: [0.38 0.5  2.42 6.13]
# Target Dates: ['2024-01-06' '2024-01-13' '2024-01-20' '2024-01-27']
# Observation: 3.0
# Observation: 6.0
# Observation: 9.0
# Observation: 8.0
#
# WIS: [0.44 3.23 7.51 5.92]
# Target Dates: ['2024-01-13' '2024-01-20' '2024-01-27' '2024-02-03']
# Observation: 6.0
# Observation: 9.0
# Observation: 8.0
# Observation: 9.0
#
# WIS: [1.17 5.36 5.08 7.1 ]
# Target Dates: ['2024-01-20' '2024-01-27' '2024-02-03' '2024-02-10']
# Observation: 9.0
# Observation: 8.0
# Observation: 9.0
# Observation: 6.0
#
# WIS: [7.54 4.76 3.51 4.19]
# Target Dates: ['2024-02-03' '2024-02-10' '2024-02-17' '2024-02-24']
# Observation: 9.0
# Observation: 6.0
# Observation: 6.0
# Observation: 2.0
#
# WIS: [6.92 3.88 2.98 0.51]
# Target Dates: ['2024-02-10' '2024-02-17' '2024-02-24' '2024-03-02']
# Observation: 6.0
# Observation: 6.0
# Observation: 2.0
# Observation: 3.0
#
# WIS: [2.56 2.01 0.34 1.25]
# Target Dates: ['2024-02-17' '2024-02-24' '2024-03-02' '2024-03-09']
# Observation: 6.0
# Observation: 2.0
# Observation: 3.0
# Observation: 4.0
#
# WIS: [1.39 1.25 1.2  0.71]
# Target Dates: ['2024-02-24' '2024-03-02' '2024-03-09' '2024-03-16']
# Observation: 2.0
# Observation: 3.0
# Observation: 4.0
# Observation: 6.0
#
# WIS: [0.39 1.74 2.6  3.45]
# Target Dates: ['2024-03-02' '2024-03-09' '2024-03-16' '2024-03-23']
# Observation: 3.0
# Observation: 4.0
# Observation: 6.0
# Observation: 10.0
#
# WIS: [0.33 0.8  1.11 8.87]
# Target Dates: ['2024-03-09' '2024-03-16' '2024-03-23' '2024-03-30']
# Observation: 4.0
# Observation: 6.0
# Observation: 10.0
# Observation: 7.0
#
# WIS: [0.6  1.63 3.2  5.87]
# Target Dates: ['2024-03-16' '2024-03-23' '2024-03-30' '2024-04-06']
# Observation: 6.0
# Observation: 10.0
# Observation: 7.0
# Observation: 12.0
#
# WIS: [1.54 5.68 4.86 5.38]
# Target Dates: ['2024-03-23' '2024-03-30' '2024-04-06' '2024-04-13']
# Observation: 10.0
# Observation: 7.0
# Observation: 12.0
# Observation: 11.0
#
# WIS: [5.64 5.17 6.3  7.73]
# Target Dates: ['2024-03-30' '2024-04-06' '2024-04-13' '2024-04-20']
# Observation: 7.0
# Observation: 12.0
# Observation: 11.0
# Observation: 3.0
#
# WIS: [ 2.64 10.17  5.3   0.42]
# Target Dates: ['2024-04-06' '2024-04-13' '2024-04-20' '2024-04-27']
# Observation: 12.0
# Observation: 11.0
# Observation: 3.0
# Observation: 6.0
#
# WIS: [3.53 7.82 1.45 3.69]
# Target Dates: ['2023-10-14' '2023-10-21' '2023-10-28' '2023-11-04' '2023-11-11']
# Observation: 24.0
# Observation: 34.0
# Observation: 35.0
# Observation: 46.0
#
# WIS: [13.96 20.47 26.59 32.46]
# Target Dates: ['2023-10-21' '2023-10-28' '2023-11-04' '2023-11-11' '2023-11-18']
# Observation: 34.0
# Observation: 35.0
# Observation: 46.0
# Observation: 85.0
#
# WIS: [11.13  7.98 17.58 64.31]
# Target Dates: ['2023-10-28' '2023-11-04' '2023-11-11' '2023-11-18' '2023-11-25']
# Observation: 35.0
# Observation: 46.0
# Observation: 85.0
# Observation: 145.0
#
# WIS: [ 12.13  18.74  56.58 124.31]
# Target Dates: ['2023-11-11' '2023-11-18' '2023-11-25' '2023-12-02']
# Observation: 85.0
# Observation: 145.0
# Observation: 176.0
# Observation: 232.0
#
# WIS: [ 28.2   79.27  98.32 141.61]
# Target Dates: ['2023-11-18' '2023-11-25' '2023-12-02' '2023-12-09']
# Observation: 145.0
# Observation: 176.0
# Observation: 232.0
# Observation: 323.0
#
# WIS: [ 88.2  110.27 154.32 232.61]
# Target Dates: ['2023-11-25' '2023-12-02' '2023-12-09' '2023-12-16']
# Observation: 176.0
# Observation: 232.0
# Observation: 323.0
# Observation: 456.0
#
# WIS: [ 34.62  51.55  89.54 158.12]
# Target Dates: ['2023-12-02' '2023-12-09' '2023-12-16' '2023-12-23']
# Observation: 232.0
# Observation: 323.0
# Observation: 456.0
# Observation: 722.0
#
# WIS: [ 14.08  23.61  50.7  191.4 ]
# Target Dates: ['2023-12-09' '2023-12-16' '2023-12-23' '2023-12-30']
# Observation: 323.0
# Observation: 456.0
# Observation: 722.0
# Observation: 898.0
#
# WIS: [ 36.13  81.89 119.06 333.32]
# Target Dates: ['2023-12-16' '2023-12-23' '2023-12-30' '2024-01-06']
# Observation: 456.0
# Observation: 722.0
# Observation: 898.0
# Observation: 946.0
#
# WIS: [ 22.45  40.76  58.83 261.04]
# Target Dates: ['2023-12-23' '2023-12-30' '2024-01-06' '2024-01-13']
# Observation: 722.0
# Observation: 898.0
# Observation: 946.0
# Observation: 862.0
#
# WIS: [ 77.31  55.19  95.74 482.76]
# Target Dates: ['2023-12-30' '2024-01-06' '2024-01-13' '2024-01-20']
# Observation: 898.0
# Observation: 946.0
# Observation: 862.0
# Observation: 740.0
#
# WIS: [ 190.05  532.57 1120.86 1872.3 ]
# Target Dates: ['2024-01-06' '2024-01-13' '2024-01-20' '2024-01-27']
# Observation: 946.0
# Observation: 862.0
# Observation: 740.0
# Observation: 622.0
#
# WIS: [ 545.17 1138.66 1888.5  2752.71]
# Target Dates: ['2024-01-13' '2024-01-20' '2024-01-27' '2024-02-03']
# Observation: 862.0
# Observation: 740.0
# Observation: 622.0
# Observation: 507.0
#
# WIS: [ 669.   1275.98 2005.39 2830.31]
# Target Dates: ['2024-01-20' '2024-01-27' '2024-02-03' '2024-02-10']
# Observation: 740.0
# Observation: 622.0
# Observation: 507.0
# Observation: 335.0
#
# WIS: [ 695.54 1198.3  1764.34 2431.39]
# Target Dates: ['2024-02-03' '2024-02-10' '2024-02-17' '2024-02-24']
# Observation: 507.0
# Observation: 335.0
# Observation: 272.0
# Observation: 212.0
#
# WIS: [ 17.94  89.52  94.83 102.97]
# Target Dates: ['2024-02-10' '2024-02-17' '2024-02-24' '2024-03-02']
# Observation: 335.0
# Observation: 272.0
# Observation: 212.0
# Observation: 191.0
#
# WIS: [29.82 31.02 39.63 21.69]
# Target Dates: ['2024-02-17' '2024-02-24' '2024-03-02' '2024-03-09']
# Observation: 272.0
# Observation: 212.0
# Observation: 191.0
# Observation: 148.0
#
# WIS: [20.47 11.22 21.07 16.33]
# Target Dates: ['2024-02-24' '2024-03-02' '2024-03-09' '2024-03-16']
# Observation: 212.0
# Observation: 191.0
# Observation: 148.0
# Observation: 159.0
#
# WIS: [24.63 37.07 29.43 59.78]
# Target Dates: ['2024-03-02' '2024-03-09' '2024-03-16' '2024-03-23']
# Observation: 191.0
# Observation: 148.0
# Observation: 159.0
# Observation: 118.0
#
# WIS: [29.62 20.65 47.75 30.57]
# Target Dates: ['2024-03-09' '2024-03-16' '2024-03-23' '2024-03-30']
# Observation: 148.0
# Observation: 159.0
# Observation: 118.0
# Observation: 104.0
#
# WIS: [ 8.17 28.78 17.44 20.23]
# Target Dates: ['2024-03-16' '2024-03-23' '2024-03-30' '2024-04-06']
# Observation: 159.0
# Observation: 118.0
# Observation: 104.0
# Observation: 106.0
#
# WIS: [38.5  21.62 24.63 39.4 ]
# Target Dates: ['2024-03-23' '2024-03-30' '2024-04-06' '2024-04-13']
# Observation: 118.0
# Observation: 104.0
# Observation: 106.0
# Observation: 91.0
#
# WIS: [16.47 20.9  34.37 31.74]
# Target Dates: ['2024-03-30' '2024-04-06' '2024-04-13' '2024-04-20']
# Observation: 104.0
# Observation: 106.0
# Observation: 91.0
# Observation: 77.0
#
# WIS: [ 8.52 22.55 21.67 20.03]
# Target Dates: ['2024-04-06' '2024-04-13' '2024-04-20' '2024-04-27']
# Observation: 106.0
# Observation: 91.0
# Observation: 77.0
# Observation: 92.0
#
# WIS: [27.35 26.82 22.13 46.69]
# Target Dates: ['2023-10-14' '2023-10-21' '2023-10-28' '2023-11-04' '2023-11-11']
# Observation: 14.0
# Observation: 12.0
# Observation: 17.0
# Observation: 19.0
#
# WIS: [1.82 0.96 4.9  6.27]
# Target Dates: ['2023-10-21' '2023-10-28' '2023-11-04' '2023-11-11' '2023-11-18']
# Observation: 12.0
# Observation: 17.0
# Observation: 19.0
# Observation: 23.0
#
# WIS: [0.68 1.18 3.92 5.05]
# Target Dates: ['2023-10-28' '2023-11-04' '2023-11-11' '2023-11-18' '2023-11-25']
# Observation: 17.0
# Observation: 19.0
# Observation: 23.0
# Observation: 19.0
#
# WIS: [3.94 2.39 7.18 2.12]
# Target Dates: ['2023-11-11' '2023-11-18' '2023-11-25' '2023-12-02']
# Observation: 23.0
# Observation: 19.0
# Observation: 22.0
# Observation: 18.0
#
# WIS: [4.59 2.45 3.6  1.02]
# Target Dates: ['2023-11-18' '2023-11-25' '2023-12-02' '2023-12-09']
# Observation: 19.0
# Observation: 22.0
# Observation: 18.0
# Observation: 38.0
#
# WIS: [ 2.01  4.65  1.45 16.89]
# Target Dates: ['2023-11-25' '2023-12-02' '2023-12-09' '2023-12-16']
# Observation: 22.0
# Observation: 18.0
# Observation: 38.0
# Observation: 43.0
#
# WIS: [ 1.    2.79  8.57 12.11]
# Target Dates: ['2023-12-02' '2023-12-09' '2023-12-16' '2023-12-23']
# Observation: 18.0
# Observation: 38.0
# Observation: 43.0
# Observation: 82.0
#
# WIS: [ 2.03  8.66 11.7  50.42]
# Target Dates: ['2023-12-09' '2023-12-16' '2023-12-23' '2023-12-30']
# Observation: 38.0
# Observation: 43.0
# Observation: 82.0
# Observation: 155.0
#
# WIS: [ 16.24  21.28  60.1  133.1 ]
# Target Dates: ['2023-12-16' '2023-12-23' '2023-12-30' '2024-01-06']
# Observation: 43.0
# Observation: 82.0
# Observation: 155.0
# Observation: 183.0
#
# WIS: [ 20.    57.95 129.47 159.17]
# Target Dates: ['2023-12-23' '2023-12-30' '2024-01-06' '2024-01-13']
# Observation: 82.0
# Observation: 155.0
# Observation: 183.0
# Observation: 197.0
#
# WIS: [ 34.73  94.91 111.96 111.01]
# Target Dates: ['2023-12-30' '2024-01-06' '2024-01-13' '2024-01-20']
# Observation: 155.0
# Observation: 183.0
# Observation: 197.0
# Observation: 243.0
#
# WIS: [71.73 81.65 71.25 93.16]
# Target Dates: ['2024-01-06' '2024-01-13' '2024-01-20' '2024-01-27']
# Observation: 183.0
# Observation: 197.0
# Observation: 243.0
# Observation: 250.0
#
# WIS: [ 14.43  58.06 109.91 243.84]
# Target Dates: ['2024-01-13' '2024-01-20' '2024-01-27' '2024-02-03']
# Observation: 197.0
# Observation: 243.0
# Observation: 250.0
# Observation: 233.0
#
# WIS: [108.32 199.83 393.32 688.28]
# Target Dates: ['2024-01-20' '2024-01-27' '2024-02-03' '2024-02-10']
# Observation: 243.0
# Observation: 250.0
# Observation: 233.0
# Observation: 266.0
#
# WIS: [ 96.69 229.87 442.67 690.3 ]
# Target Dates: ['2024-02-03' '2024-02-10' '2024-02-17' '2024-02-24']
# Observation: 233.0
# Observation: 266.0
# Observation: 254.0
# Observation: 263.0
#
# WIS: [ 4.5  22.84 18.64 33.43]
# Target Dates: ['2024-02-10' '2024-02-17' '2024-02-24' '2024-03-02']
# Observation: 266.0
# Observation: 254.0
# Observation: 263.0
# Observation: 260.0
#
# WIS: [18.35 12.72 17.43 18.5 ]
# Target Dates: ['2024-02-17' '2024-02-24' '2024-03-02' '2024-03-09']
# Observation: 254.0
# Observation: 263.0
# Observation: 260.0
# Observation: 267.0
#
# WIS: [ 8.78 14.52 16.18 21.68]
# Target Dates: ['2024-02-24' '2024-03-02' '2024-03-09' '2024-03-16']
# Observation: 263.0
# Observation: 260.0
# Observation: 267.0
# Observation: 235.0
#
# WIS: [12.08 12.74 18.94  3.61]
# Target Dates: ['2024-03-02' '2024-03-09' '2024-03-16' '2024-03-23']
# Observation: 260.0
# Observation: 267.0
# Observation: 235.0
# Observation: 151.0
#
# WIS: [ 4.91  7.96  7.96 80.56]
# Target Dates: ['2024-03-09' '2024-03-16' '2024-03-23' '2024-03-30']
# Observation: 267.0
# Observation: 235.0
# Observation: 151.0
# Observation: 113.0
#
# WIS: [  7.56   9.7   82.04 118.56]
# Target Dates: ['2024-03-16' '2024-03-23' '2024-03-30' '2024-04-06']
# Observation: 235.0
# Observation: 151.0
# Observation: 113.0
# Observation: 78.0
#
# WIS: [ 11.81  88.02 127.07 157.2 ]
# Target Dates: ['2024-03-23' '2024-03-30' '2024-04-06' '2024-04-13']
# Observation: 151.0
# Observation: 113.0
# Observation: 78.0
# Observation: 50.0
#
# WIS: [ 75.75 112.45 143.51 171.56]
# Target Dates: ['2024-03-30' '2024-04-06' '2024-04-13' '2024-04-20']
# Observation: 113.0
# Observation: 78.0
# Observation: 50.0
# Observation: 44.0
#
# WIS: [113.75 147.45 171.51 177.56]
# Target Dates: ['2024-04-06' '2024-04-13' '2024-04-20' '2024-04-27']
# Observation: 78.0
# Observation: 50.0
# Observation: 44.0
# Observation: 37.0
#
# WIS: [18.58 28.51 23.24 15.02]
# Target Dates: ['2023-10-14' '2023-10-21' '2023-10-28' '2023-11-04' '2023-11-11']
# Observation: 58.0
# Observation: 58.0
# Observation: 75.0
# Observation: 89.0
#
# WIS: [ 7.23  6.72 17.09 29.74]
# Target Dates: ['2023-10-21' '2023-10-28' '2023-11-04' '2023-11-11' '2023-11-18']
# Observation: 58.0
# Observation: 75.0
# Observation: 89.0
# Observation: 166.0
#
# WIS: [ 4.48  9.87 22.61 90.91]
# Target Dates: ['2023-10-28' '2023-11-04' '2023-11-11' '2023-11-18' '2023-11-25']
# Observation: 75.0
# Observation: 89.0
# Observation: 166.0
# Observation: 283.0
#
# WIS: [ 16.35  20.51  99.61 207.91]
# Target Dates: ['2023-11-11' '2023-11-18' '2023-11-25' '2023-12-02']
# Observation: 166.0
# Observation: 283.0
# Observation: 357.0
# Observation: 534.0
#
# WIS: [ 92.21 197.27 267.86 432.01]
# Target Dates: ['2023-11-18' '2023-11-25' '2023-12-02' '2023-12-09']
# Observation: 283.0
# Observation: 357.0
# Observation: 534.0
# Observation: 652.0
#
# WIS: [209.21 271.27 444.86 550.01]
# Target Dates: ['2023-11-25' '2023-12-02' '2023-12-09' '2023-12-16']
# Observation: 357.0
# Observation: 534.0
# Observation: 652.0
# Observation: 883.0
#
# WIS: [175.47 326.95 404.32 604.21]
# Target Dates: ['2023-12-02' '2023-12-09' '2023-12-16' '2023-12-23']
# Observation: 534.0
# Observation: 652.0
# Observation: 883.0
# Observation: 1348.0
#
# WIS: [ 36.8  207.16 488.59 799.45]
# Target Dates: ['2023-12-09' '2023-12-16' '2023-12-23' '2023-12-30']
# Observation: 652.0
# Observation: 883.0
# Observation: 1348.0
# Observation: 1557.0
#
# WIS: [ 30.14  60.39  76.21 183.38]
# Target Dates: ['2023-12-16' '2023-12-23' '2023-12-30' '2024-01-06']
# Observation: 883.0
# Observation: 1348.0
# Observation: 1557.0
# Observation: 1512.0
#
# WIS: [ 22.78  59.21  92.61 530.43]
# Target Dates: ['2023-12-23' '2023-12-30' '2024-01-06' '2024-01-13']
# Observation: 1348.0
# Observation: 1557.0
# Observation: 1512.0
# Observation: 1310.0
#
# WIS: [254.85 143.03 126.57 648.13]
# Target Dates: ['2023-12-30' '2024-01-06' '2024-01-13' '2024-01-20']
# Observation: 1557.0
# Observation: 1512.0
# Observation: 1310.0
# Observation: 1196.0
#
# WIS: [ 187.91  740.01 1558.09 2439.47]
# Target Dates: ['2024-01-06' '2024-01-13' '2024-01-20' '2024-01-27']
# Observation: 1512.0
# Observation: 1310.0
# Observation: 1196.0
# Observation: 824.0
#
# WIS: [ 708.5  1539.11 2388.93 3629.62]
# Target Dates: ['2024-01-13' '2024-01-20' '2024-01-27' '2024-02-03']
# Observation: 1310.0
# Observation: 1196.0
# Observation: 824.0
# Observation: 674.0
#
# WIS: [ 914.21 1563.25 2547.37 3401.47]
# Target Dates: ['2024-01-20' '2024-01-27' '2024-02-03' '2024-02-10']
# Observation: 1196.0
# Observation: 824.0
# Observation: 674.0
# Observation: 532.0
#
# WIS: [ 613.03 1320.87 1826.58 2360.51]
# Target Dates: ['2024-02-03' '2024-02-10' '2024-02-17' '2024-02-24']
# Observation: 674.0
# Observation: 532.0
# Observation: 407.0
# Observation: 314.0
#
# WIS: [32.16 30.53 26.41 21.97]
# Target Dates: ['2024-02-10' '2024-02-17' '2024-02-24' '2024-03-02']
# Observation: 532.0
# Observation: 407.0
# Observation: 314.0
# Observation: 307.0
#
# WIS: [38.59 33.46 29.86 70.75]
# Target Dates: ['2024-02-17' '2024-02-24' '2024-03-02' '2024-03-09']
# Observation: 407.0
# Observation: 314.0
# Observation: 307.0
# Observation: 229.0
#
# WIS: [40.5  32.98 72.57 51.38]
# Target Dates: ['2024-02-24' '2024-03-02' '2024-03-09' '2024-03-16']
# Observation: 314.0
# Observation: 307.0
# Observation: 229.0
# Observation: 218.0
#
# WIS: [34.64 66.3  49.43 70.4 ]
# Target Dates: ['2024-03-02' '2024-03-09' '2024-03-16' '2024-03-23']
# Observation: 307.0
# Observation: 229.0
# Observation: 218.0
# Observation: 183.0
#
# WIS: [72.13 53.37 76.43 74.41]
# Target Dates: ['2024-03-09' '2024-03-16' '2024-03-23' '2024-03-30']
# Observation: 229.0
# Observation: 218.0
# Observation: 183.0
# Observation: 148.0
#
# WIS: [22.2  44.98 45.54 42.79]
# Target Dates: ['2024-03-16' '2024-03-23' '2024-03-30' '2024-04-06']
# Observation: 218.0
# Observation: 183.0
# Observation: 148.0
# Observation: 152.0
#
# WIS: [59.81 55.29 45.   73.86]
# Target Dates: ['2024-03-23' '2024-03-30' '2024-04-06' '2024-04-13']
# Observation: 183.0
# Observation: 148.0
# Observation: 152.0
# Observation: 169.0
#
# WIS: [57.   49.18 68.03 98.06]
# Target Dates: ['2024-03-30' '2024-04-06' '2024-04-13' '2024-04-20']
# Observation: 148.0
# Observation: 152.0
# Observation: 169.0
# Observation: 157.0
#
# WIS: [30.98 53.11 85.03 86.06]
# Target Dates: ['2024-04-06' '2024-04-13' '2024-04-20' '2024-04-27']
# Observation: 152.0
# Observation: 169.0
# Observation: 157.0
# Observation: 144.0
#
# WIS: [37.16 73.76 75.11 69.16]
# Target Dates: ['2023-10-14' '2023-10-21' '2023-10-28' '2023-11-04' '2023-11-11']
# Observation: 11.0
# Observation: 15.0
# Observation: 19.0
# Observation: 23.0
#
# WIS: [ 2.72  5.29  5.67 11.67]
# Target Dates: ['2023-10-21' '2023-10-28' '2023-11-04' '2023-11-11' '2023-11-18']
# Observation: 15.0
# Observation: 19.0
# Observation: 23.0
# Observation: 33.0
#
# WIS: [1.83 2.64 2.91 7.83]
# Target Dates: ['2023-10-28' '2023-11-04' '2023-11-11' '2023-11-18' '2023-11-25']
# Observation: 19.0
# Observation: 23.0
# Observation: 33.0
# Observation: 88.0
#
# WIS: [ 2.    5.21  9.84 61.92]
# Target Dates: ['2023-11-11' '2023-11-18' '2023-11-25' '2023-12-02']
# Observation: 33.0
# Observation: 88.0
# Observation: 104.0
# Observation: 123.0
#
# WIS: [ 6.01 52.67 56.11 68.28]
# Target Dates: ['2023-11-18' '2023-11-25' '2023-12-02' '2023-12-09']
# Observation: 88.0
# Observation: 104.0
# Observation: 123.0
# Observation: 148.0
#
# WIS: [57.49 68.67 75.11 93.28]
# Target Dates: ['2023-11-25' '2023-12-02' '2023-12-09' '2023-12-16']
# Observation: 104.0
# Observation: 123.0
# Observation: 148.0
# Observation: 189.0
#
# WIS: [33.85 34.49 29.61 34.86]
# Target Dates: ['2023-12-02' '2023-12-09' '2023-12-16' '2023-12-23']
# Observation: 123.0
# Observation: 148.0
# Observation: 189.0
# Observation: 218.0
#
# WIS: [11.01 10.66 14.13 20.3 ]
# Target Dates: ['2023-12-09' '2023-12-16' '2023-12-23' '2023-12-30']
# Observation: 148.0
# Observation: 189.0
# Observation: 218.0
# Observation: 285.0
#
# WIS: [ 64.36 152.03 333.87 593.16]
# Target Dates: ['2023-12-16' '2023-12-23' '2023-12-30' '2024-01-06']
# Observation: 189.0
# Observation: 218.0
# Observation: 285.0
# Observation: 283.0
#
# WIS: [ 22.01  73.08 132.25 316.8 ]
# Target Dates: ['2023-12-23' '2023-12-30' '2024-01-06' '2024-01-13']
# Observation: 218.0
# Observation: 285.0
# Observation: 283.0
# Observation: 289.0
#
# WIS: [ 17.    31.99 137.49 287.5 ]
# Target Dates: ['2023-12-30' '2024-01-06' '2024-01-13' '2024-01-20']
# Observation: 285.0
# Observation: 283.0
# Observation: 289.0
# Observation: 224.0
#
# WIS: [ 54.17 167.02 316.04 577.45]
# Target Dates: ['2024-01-06' '2024-01-13' '2024-01-20' '2024-01-27']
# Observation: 283.0
# Observation: 289.0
# Observation: 224.0
# Observation: 232.0
#
# WIS: [151.86 279.3  516.35 726.53]
# Target Dates: ['2024-01-13' '2024-01-20' '2024-01-27' '2024-02-03']
# Observation: 289.0
# Observation: 224.0
# Observation: 232.0
# Observation: 213.0
#
# WIS: [179.25 381.28 543.51 773.64]
# Target Dates: ['2024-01-20' '2024-01-27' '2024-02-03' '2024-02-10']
# Observation: 224.0
# Observation: 232.0
# Observation: 213.0
# Observation: 204.0
#
# WIS: [230.13 331.91 484.62 648.71]
# Target Dates: ['2024-02-03' '2024-02-10' '2024-02-17' '2024-02-24']
# Observation: 213.0
# Observation: 204.0
# Observation: 146.0
# Observation: 136.0
#
# WIS: [31.51 53.04 25.97 43.32]
# Target Dates: ['2024-02-10' '2024-02-17' '2024-02-24' '2024-03-02']
# Observation: 204.0
# Observation: 146.0
# Observation: 136.0
# Observation: 109.0
#
# WIS: [33.68 13.13 25.68 26.46]
# Target Dates: ['2024-02-17' '2024-02-24' '2024-03-02' '2024-03-09']
# Observation: 146.0
# Observation: 136.0
# Observation: 109.0
# Observation: 102.0
#
# WIS: [ 6.65 13.85  8.21 26.08]
# Target Dates: ['2024-02-24' '2024-03-02' '2024-03-09' '2024-03-16']
# Observation: 136.0
# Observation: 109.0
# Observation: 102.0
# Observation: 91.0
#
# WIS: [17.06 15.39 26.64 34.36]
# Target Dates: ['2024-03-02' '2024-03-09' '2024-03-16' '2024-03-23']
# Observation: 109.0
# Observation: 102.0
# Observation: 91.0
# Observation: 75.0
#
# WIS: [11.29 24.52 28.35 25.8 ]
# Target Dates: ['2024-03-09' '2024-03-16' '2024-03-23' '2024-03-30']
# Observation: 102.0
# Observation: 91.0
# Observation: 75.0
# Observation: 82.0
#
# WIS: [ 7.22 15.   13.64 32.8 ]
# Target Dates: ['2024-03-16' '2024-03-23' '2024-03-30' '2024-04-06']
# Observation: 91.0
# Observation: 75.0
# Observation: 82.0
# Observation: 59.0
#
# WIS: [26.35 24.27 40.31 26.24]
# Target Dates: ['2024-03-23' '2024-03-30' '2024-04-06' '2024-04-13']
# Observation: 75.0
# Observation: 82.0
# Observation: 59.0
# Observation: 61.0
#
# WIS: [13.91 33.11 21.47 25.63]
# Target Dates: ['2024-03-30' '2024-04-06' '2024-04-13' '2024-04-20']
# Observation: 82.0
# Observation: 59.0
# Observation: 61.0
# Observation: 22.0
#
# WIS: [19.52 11.72 23.47  3.16]
# Target Dates: ['2024-04-06' '2024-04-13' '2024-04-20' '2024-04-27']
# Observation: 59.0
# Observation: 61.0
# Observation: 22.0
# Observation: 28.0
#
# WIS: [4.47 9.87 7.66 3.02]
# Target Dates: ['2023-10-14' '2023-10-21' '2023-10-28' '2023-11-04' '2023-11-11']
# Observation: 1.0
# Observation: 1.0
# Observation: 6.0
# Observation: 13.0
#
# WIS: [6.06 6.33 2.97 0.77]
# Target Dates: ['2023-10-21' '2023-10-28' '2023-11-04' '2023-11-11' '2023-11-18']
# Observation: 1.0
# Observation: 6.0
# Observation: 13.0
# Observation: 6.0
#
# WIS: [3.36 0.99 4.07 1.09]
# Target Dates: ['2023-10-28' '2023-11-04' '2023-11-11' '2023-11-18' '2023-11-25']
# Observation: 6.0
# Observation: 13.0
# Observation: 6.0
# Observation: 13.0
#
# WIS: [0.96 4.11 1.02 3.79]
# Target Dates: ['2023-11-11' '2023-11-18' '2023-11-25' '2023-12-02']
# Observation: 6.0
# Observation: 13.0
# Observation: 22.0
# Observation: 52.0
#
# WIS: [ 1.59  3.1  11.27 42.48]
# Target Dates: ['2023-11-18' '2023-11-25' '2023-12-02' '2023-12-09']
# Observation: 13.0
# Observation: 22.0
# Observation: 52.0
# Observation: 59.0
#
# WIS: [ 2.83 11.27 41.27 49.48]
# Target Dates: ['2023-11-25' '2023-12-02' '2023-12-09' '2023-12-16']
# Observation: 22.0
# Observation: 52.0
# Observation: 59.0
# Observation: 96.0
#
# WIS: [ 8.41 40.46 45.89 82.9 ]
# Target Dates: ['2023-12-02' '2023-12-09' '2023-12-16' '2023-12-23']
# Observation: 52.0
# Observation: 59.0
# Observation: 96.0
# Observation: 96.0
#
# WIS: [36.6  42.21 75.65 75.08]
# Target Dates: ['2023-12-09' '2023-12-16' '2023-12-23' '2023-12-30']
# Observation: 59.0
# Observation: 96.0
# Observation: 96.0
# Observation: 165.0
#
# WIS: [ 7.97 16.08 18.28 28.95]
# Target Dates: ['2023-12-16' '2023-12-23' '2023-12-30' '2024-01-06']
# Observation: 96.0
# Observation: 96.0
# Observation: 165.0
# Observation: 166.0
#
# WIS: [ 8.08 19.98 19.6  82.11]
# Target Dates: ['2023-12-23' '2023-12-30' '2024-01-06' '2024-01-13']
# Observation: 96.0
# Observation: 165.0
# Observation: 166.0
# Observation: 163.0
#
# WIS: [ 20.52  21.73 105.71 261.66]
# Target Dates: ['2023-12-30' '2024-01-06' '2024-01-13' '2024-01-20']
# Observation: 165.0
# Observation: 166.0
# Observation: 163.0
# Observation: 150.0
#
# WIS: [ 27.14 107.53 232.11 415.77]
# Target Dates: ['2024-01-06' '2024-01-13' '2024-01-20' '2024-01-27']
# Observation: 166.0
# Observation: 163.0
# Observation: 150.0
# Observation: 164.0
#
# WIS: [ 93.01 211.95 391.32 613.48]
# Target Dates: ['2024-01-13' '2024-01-20' '2024-01-27' '2024-02-03']
# Observation: 163.0
# Observation: 150.0
# Observation: 164.0
# Observation: 125.0
#
# WIS: [111.   230.53 364.48 612.14]
# Target Dates: ['2024-01-20' '2024-01-27' '2024-02-03' '2024-02-10']
# Observation: 150.0
# Observation: 164.0
# Observation: 125.0
# Observation: 142.0
#
# WIS: [121.37 196.78 364.27 509.53]
# Target Dates: ['2024-02-03' '2024-02-10' '2024-02-17' '2024-02-24']
# Observation: 125.0
# Observation: 142.0
# Observation: 106.0
# Observation: 116.0
#
# WIS: [ 5.96 33.47 23.22 48.68]
# Target Dates: ['2024-02-10' '2024-02-17' '2024-02-24' '2024-03-02']
# Observation: 142.0
# Observation: 106.0
# Observation: 116.0
# Observation: 164.0
#
# WIS: [ 38.15  22.41  45.85 110.67]
# Target Dates: ['2024-02-17' '2024-02-24' '2024-03-02' '2024-03-09']
# Observation: 106.0
# Observation: 116.0
# Observation: 164.0
# Observation: 168.0
#
# WIS: [ 5.88 21.88 86.85 96.06]
# Target Dates: ['2024-02-24' '2024-03-02' '2024-03-09' '2024-03-16']
# Observation: 116.0
# Observation: 164.0
# Observation: 168.0
# Observation: 142.0
#
# WIS: [11.55 66.28 82.33 63.06]
# Target Dates: ['2024-03-02' '2024-03-09' '2024-03-16' '2024-03-23']
# Observation: 164.0
# Observation: 168.0
# Observation: 142.0
# Observation: 104.0
#
# WIS: [20.71 30.12 13.1   8.46]
# Target Dates: ['2024-03-09' '2024-03-16' '2024-03-23' '2024-03-30']
# Observation: 168.0
# Observation: 142.0
# Observation: 104.0
# Observation: 94.0
#
# WIS: [23.66 12.39  8.71 11.15]
# Target Dates: ['2024-03-16' '2024-03-23' '2024-03-30' '2024-04-06']
# Observation: 142.0
# Observation: 104.0
# Observation: 94.0
# Observation: 72.0
#
# WIS: [ 6.25 25.41 35.7  55.7 ]
# Target Dates: ['2024-03-23' '2024-03-30' '2024-04-06' '2024-04-13']
# Observation: 104.0
# Observation: 94.0
# Observation: 72.0
# Observation: 60.0
#
# WIS: [14.94 21.02 40.69 52.03]
# Target Dates: ['2024-03-30' '2024-04-06' '2024-04-13' '2024-04-20']
# Observation: 94.0
# Observation: 72.0
# Observation: 60.0
# Observation: 63.0
#
# WIS: [22.44 43.02 52.69 49.03]
# Target Dates: ['2024-04-06' '2024-04-13' '2024-04-20' '2024-04-27']
# Observation: 72.0
# Observation: 60.0
# Observation: 63.0
# Observation: 46.0
#
# WIS: [17.05 27.42 18.81 31.11]
# Target Dates: ['2023-10-14' '2023-10-21' '2023-10-28' '2023-11-04' '2023-11-11']
# Observation: 0.0
# Observation: 0.0
# Observation: 1.0
# Observation: 0.0
#
# WIS: [0. 0. 1. 0.]
# Target Dates: ['2023-10-21' '2023-10-28' '2023-11-04' '2023-11-11' '2023-11-18']
# Observation: 0.0
# Observation: 1.0
# Observation: 0.0
# Observation: 1.0
#
# WIS: [0.14 0.53 0.14 0.54]
# Target Dates: ['2023-10-28' '2023-11-04' '2023-11-11' '2023-11-18' '2023-11-25']
# Observation: 1.0
# Observation: 0.0
# Observation: 1.0
# Observation: 1.0
#
# WIS: [0.53 0.14 0.53 0.54]
# Target Dates: ['2023-11-11' '2023-11-18' '2023-11-25' '2023-12-02']
# Observation: 1.0
# Observation: 1.0
# Observation: 2.0
# Observation: 1.0
#
# WIS: [0.33 0.71 0.18 0.82]
# Target Dates: ['2023-11-18' '2023-11-25' '2023-12-02' '2023-12-09']
# Observation: 1.0
# Observation: 2.0
# Observation: 1.0
# Observation: 8.0
#
# WIS: [0.33 1.6  0.57 4.21]
# Target Dates: ['2023-11-25' '2023-12-02' '2023-12-09' '2023-12-16']
# Observation: 2.0
# Observation: 1.0
# Observation: 8.0
# Observation: 11.0
#
# WIS: [0.37 0.76 5.17 7.14]
# Target Dates: ['2023-12-02' '2023-12-09' '2023-12-16' '2023-12-23']
# Observation: 1.0
# Observation: 8.0
# Observation: 11.0
# Observation: 19.0
#
# WIS: [ 0.7   4.86  4.94 10.73]
# Target Dates: ['2023-12-09' '2023-12-16' '2023-12-23' '2023-12-30']
# Observation: 8.0
# Observation: 11.0
# Observation: 19.0
# Observation: 35.0
#
# WIS: [ 1.36  8.74 15.81 30.99]
# Target Dates: ['2023-12-16' '2023-12-23' '2023-12-30' '2024-01-06']
# Observation: 11.0
# Observation: 19.0
# Observation: 35.0
# Observation: 42.0
#
# WIS: [ 2.47  5.14 15.07 14.06]
# Target Dates: ['2023-12-23' '2023-12-30' '2024-01-06' '2024-01-13']
# Observation: 19.0
# Observation: 35.0
# Observation: 42.0
# Observation: 40.0
#
# WIS: [ 5.8  13.79 12.59  6.14]
# Target Dates: ['2023-12-30' '2024-01-06' '2024-01-13' '2024-01-20']
# Observation: 35.0
# Observation: 42.0
# Observation: 40.0
# Observation: 35.0
#
# WIS: [ 1.66  7.59 25.11 45.54]
# Target Dates: ['2024-01-06' '2024-01-13' '2024-01-20' '2024-01-27']
# Observation: 42.0
# Observation: 40.0
# Observation: 35.0
# Observation: 33.0
#
# WIS: [ 37.6   79.55 130.42 172.54]
# Target Dates: ['2024-01-13' '2024-01-20' '2024-01-27' '2024-02-03']
# Observation: 40.0
# Observation: 35.0
# Observation: 33.0
# Observation: 24.0
#
# WIS: [27.84 56.76 71.09 85.83]
# Target Dates: ['2024-01-20' '2024-01-27' '2024-02-03' '2024-02-10']
# Observation: 35.0
# Observation: 33.0
# Observation: 24.0
# Observation: 26.0
#
# WIS: [18.56 28.86 43.83 44.28]
# Target Dates: ['2024-02-03' '2024-02-10' '2024-02-17' '2024-02-24']
# Observation: 24.0
# Observation: 26.0
# Observation: 30.0
# Observation: 31.0
#
# WIS: [ 4.46 13.29 21.48 26.43]
# Target Dates: ['2024-02-10' '2024-02-17' '2024-02-24' '2024-03-02']
# Observation: 26.0
# Observation: 30.0
# Observation: 31.0
# Observation: 25.0
#
# WIS: [11.29 19.01 22.77 20.44]
# Target Dates: ['2024-02-17' '2024-02-24' '2024-03-02' '2024-03-09']
# Observation: 30.0
# Observation: 31.0
# Observation: 25.0
# Observation: 26.0
#
# WIS: [14.51 20.06 19.68 23.91]
# Target Dates: ['2024-02-24' '2024-03-02' '2024-03-09' '2024-03-16']
# Observation: 31.0
# Observation: 25.0
# Observation: 26.0
# Observation: 28.0
#
# WIS: [ 5.24  3.5   8.04 13.59]
# Target Dates: ['2024-03-02' '2024-03-09' '2024-03-16' '2024-03-23']
# Observation: 25.0
# Observation: 26.0
# Observation: 28.0
# Observation: 25.0
#
# WIS: [ 4.44 10.37 12.07  7.51]
# Target Dates: ['2024-03-09' '2024-03-16' '2024-03-23' '2024-03-30']
# Observation: 26.0
# Observation: 28.0
# Observation: 25.0
# Observation: 23.0
#
# WIS: [ 4.84 12.19  9.33  6.22]
# Target Dates: ['2024-03-16' '2024-03-23' '2024-03-30' '2024-04-06']
# Observation: 28.0
# Observation: 25.0
# Observation: 23.0
# Observation: 24.0
#
# WIS: [3.21 2.06 2.28 2.38]
# Target Dates: ['2024-03-23' '2024-03-30' '2024-04-06' '2024-04-13']
# Observation: 25.0
# Observation: 23.0
# Observation: 24.0
# Observation: 8.0
#
# WIS: [4.08 2.87 4.33 2.64]
# Target Dates: ['2024-03-30' '2024-04-06' '2024-04-13' '2024-04-20']
# Observation: 23.0
# Observation: 24.0
# Observation: 8.0
# Observation: 12.0
#
# WIS: [3.09 3.35 5.42 1.3 ]
# Target Dates: ['2024-04-06' '2024-04-13' '2024-04-20' '2024-04-27']
# Observation: 24.0
# Observation: 8.0
# Observation: 12.0
# Observation: 10.0
#
# WIS: [6.16 2.5  1.62 1.41]
# Target Dates: ['2023-10-14' '2023-10-21' '2023-10-28' '2023-11-04' '2023-11-11']
# Observation: 3.0
# Observation: 3.0
# Observation: 0.0
# Observation: 2.0
#
# WIS: [2.24 2.24 0.   1.98]
# Target Dates: ['2023-10-21' '2023-10-28' '2023-11-04' '2023-11-11' '2023-11-18']
# Observation: 3.0
# Observation: 0.0
# Observation: 2.0
# Observation: 2.0
#
# WIS: [0.71 1.09 0.46 0.47]
# Target Dates: ['2023-10-28' '2023-11-04' '2023-11-11' '2023-11-18' '2023-11-25']
# Observation: 0.0
# Observation: 2.0
# Observation: 2.0
# Observation: 5.0
#
# WIS: [1.09 0.49 0.46 1.67]
# Target Dates: ['2023-11-11' '2023-11-18' '2023-11-25' '2023-12-02']
# Observation: 2.0
# Observation: 5.0
# Observation: 6.0
# Observation: 10.0
#
# WIS: [0.28 2.4  3.13 6.97]
# Target Dates: ['2023-11-18' '2023-11-25' '2023-12-02' '2023-12-09']
# Observation: 5.0
# Observation: 6.0
# Observation: 10.0
# Observation: 12.0
#
# WIS: [2.61 3.33 7.09 8.97]
# Target Dates: ['2023-11-25' '2023-12-02' '2023-12-09' '2023-12-16']
# Observation: 6.0
# Observation: 10.0
# Observation: 12.0
# Observation: 20.0
#
# WIS: [ 4.82  8.01  6.71 14.54]
# Target Dates: ['2023-12-02' '2023-12-09' '2023-12-16' '2023-12-23']
# Observation: 10.0
# Observation: 12.0
# Observation: 20.0
# Observation: 35.0
#
# WIS: [ 4.5   8.34 15.73 30.39]
# Target Dates: ['2023-12-09' '2023-12-16' '2023-12-23' '2023-12-30']
# Observation: 12.0
# Observation: 20.0
# Observation: 35.0
# Observation: 48.0
#
# WIS: [  5.2   20.43  61.12 182.22]
# Target Dates: ['2023-12-16' '2023-12-23' '2023-12-30' '2024-01-06']
# Observation: 20.0
# Observation: 35.0
# Observation: 48.0
# Observation: 47.0
#
# WIS: [ 1.98  4.97 14.99 58.22]
# Target Dates: ['2023-12-23' '2023-12-30' '2024-01-06' '2024-01-13']
# Observation: 35.0
# Observation: 48.0
# Observation: 47.0
# Observation: 40.0
#
# WIS: [10.32 10.07  4.63 22.19]
# Target Dates: ['2023-12-30' '2024-01-06' '2024-01-13' '2024-01-20']
# Observation: 48.0
# Observation: 47.0
# Observation: 40.0
# Observation: 33.0
#
# WIS: [ 3.74 10.15 34.9  79.45]
# Target Dates: ['2024-01-06' '2024-01-13' '2024-01-20' '2024-01-27']
# Observation: 47.0
# Observation: 40.0
# Observation: 33.0
# Observation: 22.0
#
# WIS: [ 24.73  73.73 149.31 274.73]
# Target Dates: ['2024-01-13' '2024-01-20' '2024-01-27' '2024-02-03']
# Observation: 40.0
# Observation: 33.0
# Observation: 22.0
# Observation: 24.0
#
# WIS: [ 41.5   82.41 152.56 235.07]
# Target Dates: ['2024-01-20' '2024-01-27' '2024-02-03' '2024-02-10']
# Observation: 33.0
# Observation: 22.0
# Observation: 24.0
# Observation: 18.0
#
# WIS: [ 41.17  85.17 127.67 193.  ]
# Target Dates: ['2024-02-03' '2024-02-10' '2024-02-17' '2024-02-24']
# Observation: 24.0
# Observation: 18.0
# Observation: 16.0
# Observation: 16.0
#
# WIS: [3.72 3.55 5.1  4.68]
# Target Dates: ['2024-02-10' '2024-02-17' '2024-02-24' '2024-03-02']
# Observation: 18.0
# Observation: 16.0
# Observation: 16.0
# Observation: 16.0
#
# WIS: [4.87 6.06 5.71 7.  ]
# Target Dates: ['2024-02-17' '2024-02-24' '2024-03-02' '2024-03-09']
# Observation: 16.0
# Observation: 16.0
# Observation: 16.0
# Observation: 24.0
#
# WIS: [ 7.36  9.67 11.03 20.13]
# Target Dates: ['2024-02-24' '2024-03-02' '2024-03-09' '2024-03-16']
# Observation: 16.0
# Observation: 16.0
# Observation: 24.0
# Observation: 21.0
#
# WIS: [ 2.62  7.05 12.77 14.37]
# Target Dates: ['2024-03-02' '2024-03-09' '2024-03-16' '2024-03-23']
# Observation: 16.0
# Observation: 24.0
# Observation: 21.0
# Observation: 22.0
#
# WIS: [ 6.43 18.11 14.16 15.83]
# Target Dates: ['2024-03-09' '2024-03-16' '2024-03-23' '2024-03-30']
# Observation: 24.0
# Observation: 21.0
# Observation: 22.0
# Observation: 24.0
#
# WIS: [14.43 15.11 15.16 17.83]
# Target Dates: ['2024-03-16' '2024-03-23' '2024-03-30' '2024-04-06']
# Observation: 21.0
# Observation: 22.0
# Observation: 24.0
# Observation: 23.0
#
# WIS: [ 5.65  8.84 11.57  9.72]
# Target Dates: ['2024-03-23' '2024-03-30' '2024-04-06' '2024-04-13']
# Observation: 22.0
# Observation: 24.0
# Observation: 23.0
# Observation: 20.0
#
# WIS: [ 4.51 11.47  7.23  7.81]
# Target Dates: ['2024-03-30' '2024-04-06' '2024-04-13' '2024-04-20']
# Observation: 24.0
# Observation: 23.0
# Observation: 20.0
# Observation: 21.0
#
# WIS: [ 5.47 10.47  5.52  8.64]
# Target Dates: ['2024-04-06' '2024-04-13' '2024-04-20' '2024-04-27']
# Observation: 23.0
# Observation: 20.0
# Observation: 21.0
# Observation: 13.0
#
# WIS: [4.19 3.07 4.04 2.2 ]
# Target Dates: ['2023-10-14' '2023-10-21' '2023-10-28' '2023-11-04' '2023-11-11']
# Observation: 216.0
# Observation: 257.0
# Observation: 255.0
# Observation: 344.0
#
# WIS: [ 16.57  46.29  38.58 118.84]
# Target Dates: ['2023-10-21' '2023-10-28' '2023-11-04' '2023-11-11' '2023-11-18']
# Observation: 257.0
# Observation: 255.0
# Observation: 344.0
# Observation: 438.0
#
# WIS: [ 54.96  35.79 110.99 193.84]
# Target Dates: ['2023-10-28' '2023-11-04' '2023-11-11' '2023-11-18' '2023-11-25']
# Observation: 255.0
# Observation: 344.0
# Observation: 438.0
# Observation: 541.0
#
# WIS: [ 53.13 118.28 204.66 296.84]
# Target Dates: ['2023-11-11' '2023-11-18' '2023-11-25' '2023-12-02']
# Observation: 438.0
# Observation: 541.0
# Observation: 598.0
# Observation: 683.0
#
# WIS: [112.41 203.68 245.43 303.25]
# Target Dates: ['2023-11-18' '2023-11-25' '2023-12-02' '2023-12-09']
# Observation: 541.0
# Observation: 598.0
# Observation: 683.0
# Observation: 776.0
#
# WIS: [215.41 260.68 330.43 396.25]
# Target Dates: ['2023-11-25' '2023-12-02' '2023-12-09' '2023-12-16']
# Observation: 598.0
# Observation: 683.0
# Observation: 776.0
# Observation: 820.0
#
# WIS: [173.78 222.04 264.06 271.3 ]
# Target Dates: ['2023-12-02' '2023-12-09' '2023-12-16' '2023-12-23']
# Observation: 683.0
# Observation: 776.0
# Observation: 820.0
# Observation: 876.0
#
# WIS: [20.03 27.82 53.43 95.72]
# Target Dates: ['2023-12-09' '2023-12-16' '2023-12-23' '2023-12-30']
# Observation: 776.0
# Observation: 820.0
# Observation: 876.0
# Observation: 1109.0
#
# WIS: [24.21 38.75 73.18 53.49]
# Target Dates: ['2023-12-16' '2023-12-23' '2023-12-30' '2024-01-06']
# Observation: 820.0
# Observation: 876.0
# Observation: 1109.0
# Observation: 1313.0
#
# WIS: [ 20.99  31.05  43.87 101.14]
# Target Dates: ['2023-12-23' '2023-12-30' '2024-01-06' '2024-01-13']
# Observation: 876.0
# Observation: 1109.0
# Observation: 1313.0
# Observation: 1192.0
#
# WIS: [32.45 32.93 60.25 78.4 ]
# Target Dates: ['2023-12-30' '2024-01-06' '2024-01-13' '2024-01-20']
# Observation: 1109.0
# Observation: 1313.0
# Observation: 1192.0
# Observation: 998.0
#
# WIS: [ 34.15  82.74  46.28 309.22]
# Target Dates: ['2024-01-06' '2024-01-13' '2024-01-20' '2024-01-27']
# Observation: 1313.0
# Observation: 1192.0
# Observation: 998.0
# Observation: 923.0
#
# WIS: [ 35.57 188.33 521.3  761.9 ]
# Target Dates: ['2024-01-13' '2024-01-20' '2024-01-27' '2024-02-03']
# Observation: 1192.0
# Observation: 998.0
# Observation: 923.0
# Observation: 782.0
#
# WIS: [ 252.8   615.53  892.17 1233.69]
# Target Dates: ['2024-01-20' '2024-01-27' '2024-02-03' '2024-02-10']
# Observation: 998.0
# Observation: 923.0
# Observation: 782.0
# Observation: 799.0
#
# WIS: [368.6  581.79 866.73 998.35]
# Target Dates: ['2024-02-03' '2024-02-10' '2024-02-17' '2024-02-24']
# Observation: 782.0
# Observation: 799.0
# Observation: 703.0
# Observation: 668.0
#
# WIS: [43.16 21.07 28.98 23.5 ]
# Target Dates: ['2024-02-10' '2024-02-17' '2024-02-24' '2024-03-02']
# Observation: 799.0
# Observation: 703.0
# Observation: 668.0
# Observation: 597.0
#
# WIS: [45.76 35.98 59.36 53.97]
# Target Dates: ['2024-02-17' '2024-02-24' '2024-03-02' '2024-03-09']
# Observation: 703.0
# Observation: 668.0
# Observation: 597.0
# Observation: 528.0
#
# WIS: [26.43 38.78 36.03 33.54]
# Target Dates: ['2024-02-24' '2024-03-02' '2024-03-09' '2024-03-16']
# Observation: 668.0
# Observation: 597.0
# Observation: 528.0
# Observation: 551.0
#
# WIS: [37.58 35.22 30.12 83.04]
# Target Dates: ['2024-03-02' '2024-03-09' '2024-03-16' '2024-03-23']
# Observation: 597.0
# Observation: 528.0
# Observation: 551.0
# Observation: 455.0
#
# WIS: [33.93 30.37 88.   58.65]
# Target Dates: ['2024-03-09' '2024-03-16' '2024-03-23' '2024-03-30']
# Observation: 528.0
# Observation: 551.0
# Observation: 455.0
# Observation: 441.0
#
# WIS: [15.3  42.98 26.36 48.3 ]
# Target Dates: ['2024-03-16' '2024-03-23' '2024-03-30' '2024-04-06']
# Observation: 551.0
# Observation: 455.0
# Observation: 441.0
# Observation: 373.0
#
# WIS: [74.9  48.94 74.34 52.11]
# Target Dates: ['2024-03-23' '2024-03-30' '2024-04-06' '2024-04-13']
# Observation: 455.0
# Observation: 441.0
# Observation: 373.0
# Observation: 342.0
#
# WIS: [37.77 65.62 44.26 46.74]
# Target Dates: ['2024-03-30' '2024-04-06' '2024-04-13' '2024-04-20']
# Observation: 441.0
# Observation: 373.0
# Observation: 342.0
# Observation: 282.0
#
# WIS: [29.76 21.6  25.11 13.97]
# Target Dates: ['2024-04-06' '2024-04-13' '2024-04-20' '2024-04-27']
# Observation: 373.0
# Observation: 342.0
# Observation: 282.0
# Observation: 257.0
#
# WIS: [26.14 31.51 14.19 18.08]
# Target Dates: ['2023-10-14' '2023-10-21' '2023-10-28' '2023-11-04' '2023-11-11']
# Observation: 36.0
# Observation: 35.0
# Observation: 35.0
# Observation: 56.0
#
# WIS: [ 2.07  2.32  2.05 11.87]
# Target Dates: ['2023-10-21' '2023-10-28' '2023-11-04' '2023-11-11' '2023-11-18']
# Observation: 35.0
# Observation: 35.0
# Observation: 56.0
# Observation: 93.0
#
# WIS: [ 2.04  3.45  8.85 41.27]
# Target Dates: ['2023-10-28' '2023-11-04' '2023-11-11' '2023-11-18' '2023-11-25']
# Observation: 35.0
# Observation: 56.0
# Observation: 93.0
# Observation: 105.0
#
# WIS: [ 2.04 10.95 43.76 53.27]
# Target Dates: ['2023-11-11' '2023-11-18' '2023-11-25' '2023-12-02']
# Observation: 93.0
# Observation: 105.0
# Observation: 150.0
# Observation: 182.0
#
# WIS: [ 51.7   56.18 101.4  131.2 ]
# Target Dates: ['2023-11-18' '2023-11-25' '2023-12-02' '2023-12-09']
# Observation: 105.0
# Observation: 150.0
# Observation: 182.0
# Observation: 233.0
#
# WIS: [ 63.7  101.18 133.4  182.2 ]
# Target Dates: ['2023-11-25' '2023-12-02' '2023-12-09' '2023-12-16']
# Observation: 150.0
# Observation: 182.0
# Observation: 233.0
# Observation: 352.0
#
# WIS: [ 70.81  96.65 140.23 235.91]
# Target Dates: ['2023-12-02' '2023-12-09' '2023-12-16' '2023-12-23']
# Observation: 182.0
# Observation: 233.0
# Observation: 352.0
# Observation: 570.0
#
# WIS: [ 33.11  60.76 147.42 339.63]
# Target Dates: ['2023-12-09' '2023-12-16' '2023-12-23' '2023-12-30']
# Observation: 233.0
# Observation: 352.0
# Observation: 570.0
# Observation: 846.0
#
# WIS: [ 44.99 146.34 335.08 579.51]
# Target Dates: ['2023-12-16' '2023-12-23' '2023-12-30' '2024-01-06']
# Observation: 352.0
# Observation: 570.0
# Observation: 846.0
# Observation: 836.0
#
# WIS: [116.67 298.36 542.38 488.41]
# Target Dates: ['2023-12-23' '2023-12-30' '2024-01-06' '2024-01-13']
# Observation: 570.0
# Observation: 846.0
# Observation: 836.0
# Observation: 751.0
#
# WIS: [178.16 328.04 163.33  38.51]
# Target Dates: ['2023-12-30' '2024-01-06' '2024-01-13' '2024-01-20']
# Observation: 846.0
# Observation: 836.0
# Observation: 751.0
# Observation: 564.0
#
# WIS: [ 60.99  85.66 438.4  972.82]
# Target Dates: ['2024-01-06' '2024-01-13' '2024-01-20' '2024-01-27']
# Observation: 836.0
# Observation: 751.0
# Observation: 564.0
# Observation: 545.0
#
# WIS: [  67.1   388.01  881.39 1256.41]
# Target Dates: ['2024-01-13' '2024-01-20' '2024-01-27' '2024-02-03']
# Observation: 751.0
# Observation: 564.0
# Observation: 545.0
# Observation: 394.0
#
# WIS: [ 437.6   982.25 1410.44 2022.85]
# Target Dates: ['2024-01-20' '2024-01-27' '2024-02-03' '2024-02-10']
# Observation: 564.0
# Observation: 545.0
# Observation: 394.0
# Observation: 343.0
#
# WIS: [ 478.92  727.94 1147.39 1473.18]
# Target Dates: ['2024-02-03' '2024-02-10' '2024-02-17' '2024-02-24']
# Observation: 394.0
# Observation: 343.0
# Observation: 297.0
# Observation: 221.0
#
# WIS: [136.94 173.15 179.61 146.02]
# Target Dates: ['2024-02-10' '2024-02-17' '2024-02-24' '2024-03-02']
# Observation: 343.0
# Observation: 297.0
# Observation: 221.0
# Observation: 205.0
#
# WIS: [76.62 99.92 70.2  90.31]
# Target Dates: ['2024-02-17' '2024-02-24' '2024-03-02' '2024-03-09']
# Observation: 297.0
# Observation: 221.0
# Observation: 205.0
# Observation: 160.0
#
# WIS: [65.6  45.11 59.81 47.84]
# Target Dates: ['2024-02-24' '2024-03-02' '2024-03-09' '2024-03-16']
# Observation: 221.0
# Observation: 205.0
# Observation: 160.0
# Observation: 129.0
#
# WIS: [41.57 55.36 40.91 32.24]
# Target Dates: ['2024-03-02' '2024-03-09' '2024-03-16' '2024-03-23']
# Observation: 205.0
# Observation: 160.0
# Observation: 129.0
# Observation: 114.0
#
# WIS: [49.12 36.36 30.44 33.99]
# Target Dates: ['2024-03-09' '2024-03-16' '2024-03-23' '2024-03-30']
# Observation: 160.0
# Observation: 129.0
# Observation: 114.0
# Observation: 88.0
#
# WIS: [16.53 14.6  19.35 14.77]
# Target Dates: ['2024-03-16' '2024-03-23' '2024-03-30' '2024-04-06']
# Observation: 129.0
# Observation: 114.0
# Observation: 88.0
# Observation: 68.0
#
# WIS: [10.15 14.66  7.72  5.81]
# Target Dates: ['2024-03-23' '2024-03-30' '2024-04-06' '2024-04-13']
# Observation: 114.0
# Observation: 88.0
# Observation: 68.0
# Observation: 49.0
#
# WIS: [16.33  8.94  5.8   2.68]
# Target Dates: ['2024-03-30' '2024-04-06' '2024-04-13' '2024-04-20']
# Observation: 88.0
# Observation: 68.0
# Observation: 49.0
# Observation: 41.0
#
# WIS: [3.41 3.56 4.96 3.6 ]
# Target Dates: ['2024-04-06' '2024-04-13' '2024-04-20' '2024-04-27']
# Observation: 68.0
# Observation: 49.0
# Observation: 41.0
# Observation: 39.0
#
# WIS: [5.75 2.9  2.51 3.5 ]
# Target Dates: ['2023-10-14' '2023-10-21' '2023-10-28' '2023-11-04' '2023-11-11']
# Observation: 13.0
# Observation: 11.0
# Observation: 12.0
# Observation: 14.0
#
# WIS: [3.49 2.42 2.4  2.5 ]
# Target Dates: ['2023-10-21' '2023-10-28' '2023-11-04' '2023-11-11' '2023-11-18']
# Observation: 11.0
# Observation: 12.0
# Observation: 14.0
# Observation: 13.0
#
# WIS: [0.72 1.41 0.87 1.96]
# Target Dates: ['2023-10-28' '2023-11-04' '2023-11-11' '2023-11-18' '2023-11-25']
# Observation: 12.0
# Observation: 14.0
# Observation: 13.0
# Observation: 26.0
#
# WIS: [0.56 0.76 0.5  7.52]
# Target Dates: ['2023-11-11' '2023-11-18' '2023-11-25' '2023-12-02']
# Observation: 13.0
# Observation: 26.0
# Observation: 26.0
# Observation: 20.0
#
# WIS: [0.61 8.02 5.53 1.94]
# Target Dates: ['2023-11-18' '2023-11-25' '2023-12-02' '2023-12-09']
# Observation: 26.0
# Observation: 26.0
# Observation: 20.0
# Observation: 30.0
#
# WIS: [11.06  8.02  1.38  9.16]
# Target Dates: ['2023-11-25' '2023-12-02' '2023-12-09' '2023-12-16']
# Observation: 26.0
# Observation: 20.0
# Observation: 30.0
# Observation: 24.0
#
# WIS: [6.42 1.28 5.03 1.45]
# Target Dates: ['2023-12-02' '2023-12-09' '2023-12-16' '2023-12-23']
# Observation: 20.0
# Observation: 30.0
# Observation: 24.0
# Observation: 30.0
#
# WIS: [1.56 2.08 2.48 1.78]
# Target Dates: ['2023-12-09' '2023-12-16' '2023-12-23' '2023-12-30']
# Observation: 30.0
# Observation: 24.0
# Observation: 30.0
# Observation: 27.0
#
# WIS: [ 1.67  7.89  8.52 16.18]
# Target Dates: ['2023-12-16' '2023-12-23' '2023-12-30' '2024-01-06']
# Observation: 24.0
# Observation: 30.0
# Observation: 27.0
# Observation: 37.0
#
# ...
# Observation: 109.0
# Observation: 154.0
# Observation: 136.0
#
# WIS: [25.45 63.5  88.71 49.59]
# Target Dates: ['2023-12-30' '2024-01-06' '2024-01-13' '2024-01-20']
# Observation: 109.0
# Observation: 154.0
# Observation: 136.0
# Observation: 176.0
#
# WIS: [13.18 17.55 20.55 42.43]
# Target Dates: ['2024-01-06' '2024-01-13' '2024-01-20' '2024-01-27']
# Observation: 154.0
# Observation: 136.0
# Observation: 176.0
# Observation: 140.0
#
# WIS: [ 15.68 115.85 198.92 415.09]
# Target Dates: ['2024-01-13' '2024-01-20' '2024-01-27' '2024-02-03']
# Observation: 136.0
# Observation: 176.0
# Observation: 140.0
# Observation: 129.0
#
# WIS: [112.39 202.39 437.94 757.21]
# Target Dates: ['2024-01-20' '2024-01-27' '2024-02-03' '2024-02-10']
# Observation: 176.0
# Observation: 140.0
# Observation: 129.0
# Observation: 137.0
#
# WIS: [ 50.79 186.22 349.11 553.97]
# Target Dates: ['2024-02-03' '2024-02-10' '2024-02-17' '2024-02-24']
# Observation: 129.0
# Observation: 137.0
# Observation: 172.0
# Observation: 157.0
#
# WIS: [15.07  9.35 20.75 20.53]
# Target Dates: ['2024-02-10' '2024-02-17' '2024-02-24' '2024-03-02']
# Observation: 137.0
# Observation: 172.0
# Observation: 157.0
# Observation: 185.0
#
# WIS: [ 7.96 43.21 46.01 88.02]
# Target Dates: ['2024-02-17' '2024-02-24' '2024-03-02' '2024-03-09']
# Observation: 172.0
# Observation: 157.0
# Observation: 185.0
# Observation: 190.0
#
# WIS: [ 41.    43.76  88.72 116.29]
# Target Dates: ['2024-02-24' '2024-03-02' '2024-03-09' '2024-03-16']
# Observation: 157.0
# Observation: 185.0
# Observation: 190.0
# Observation: 130.0
#
# WIS: [14.88 39.18 52.52 24.72]
# Target Dates: ['2024-03-02' '2024-03-09' '2024-03-16' '2024-03-23']
# Observation: 185.0
# Observation: 190.0
# Observation: 130.0
# Observation: 107.0
#
# WIS: [31.85 46.81 16.13 12.17]
# Target Dates: ['2024-03-09' '2024-03-16' '2024-03-23' '2024-03-30']
# Observation: 190.0
# Observation: 130.0
# Observation: 107.0
# Observation: 68.0
#
# WIS: [35.54 10.88  9.11 10.37]
# Target Dates: ['2024-03-16' '2024-03-23' '2024-03-30' '2024-04-06']
# Observation: 130.0
# Observation: 107.0
# Observation: 68.0
# Observation: 51.0
#
# WIS: [ 8.69  6.72 12.99 17.53]
# Target Dates: ['2024-03-23' '2024-03-30' '2024-04-06' '2024-04-13']
# Observation: 107.0
# Observation: 68.0
# Observation: 51.0
# Observation: 44.0
#
# WIS: [ 7.07 21.14 30.4  24.75]
# Target Dates: ['2024-03-30' '2024-04-06' '2024-04-13' '2024-04-20']
# Observation: 68.0
# Observation: 51.0
# Observation: 44.0
# Observation: 17.0
#
# WIS: [30.87 38.12 37.4  51.75]
# Target Dates: ['2024-04-06' '2024-04-13' '2024-04-20' '2024-04-27']
# Observation: 51.0
# Observation: 44.0
# Observation: 17.0
# Observation: 16.0
#
# WIS: [ 9.02  8.45 18.8  13.33]
# Target Dates: ['2023-10-14' '2023-10-21' '2023-10-28' '2023-11-04' '2023-11-11']
# Observation: 7.0
# Observation: 6.0
# Observation: 6.0
# Observation: 16.0
#
# WIS: [ 2.33  1.58  1.58 11.2 ]
# Target Dates: ['2023-10-21' '2023-10-28' '2023-11-04' '2023-11-11' '2023-11-18']
# Observation: 6.0
# Observation: 6.0
# Observation: 16.0
# Observation: 20.0
#
# WIS: [0.96 1.2  3.87 5.65]
# Target Dates: ['2023-10-28' '2023-11-04' '2023-11-11' '2023-11-18' '2023-11-25']
# Observation: 6.0
# Observation: 16.0
# Observation: 20.0
# Observation: 16.0
#
# WIS: [0.96 4.6  7.71 3.11]
# Target Dates: ['2023-11-11' '2023-11-18' '2023-11-25' '2023-12-02']
# Observation: 20.0
# Observation: 16.0
# Observation: 23.0
# Observation: 33.0
#
# WIS: [ 6.53  3.98  5.88 13.65]
# Target Dates: ['2023-11-18' '2023-11-25' '2023-12-02' '2023-12-09']
# Observation: 16.0
# Observation: 23.0
# Observation: 33.0
# Observation: 70.0
#
# WIS: [ 3.63  9.71 14.03 50.29]
# Target Dates: ['2023-11-25' '2023-12-02' '2023-12-09' '2023-12-16']
# Observation: 23.0
# Observation: 33.0
# Observation: 70.0
# Observation: 96.0
#
# WIS: [ 3.89  7.84 40.01 60.29]
# Target Dates: ['2023-12-02' '2023-12-09' '2023-12-16' '2023-12-23']
# Observation: 33.0
# Observation: 70.0
# Observation: 96.0
# Observation: 182.0
#
# WIS: [  7.8   36.01  55.   133.86]
# Target Dates: ['2023-12-09' '2023-12-16' '2023-12-23' '2023-12-30']
# Observation: 70.0
# Observation: 96.0
# Observation: 182.0
# Observation: 232.0
#
# WIS: [ 9.18  7.71 25.71 20.53]
# Target Dates: ['2023-12-16' '2023-12-23' '2023-12-30' '2024-01-06']
# Observation: 96.0
# Observation: 182.0
# Observation: 232.0
# Observation: 246.0
#
# WIS: [ 5.89 32.21 22.17 25.89]
# Target Dates: ['2023-12-23' '2023-12-30' '2024-01-06' '2024-01-13']
# Observation: 182.0
# Observation: 232.0
# Observation: 246.0
# Observation: 279.0
#
# WIS: [26.   16.16 26.57 98.71]
# Target Dates: ['2023-12-30' '2024-01-06' '2024-01-13' '2024-01-20']
# Observation: 232.0
# Observation: 246.0
# Observation: 279.0
# Observation: 214.0
#
# WIS: [ 30.48 141.43 292.66 625.98]
# Target Dates: ['2024-01-06' '2024-01-13' '2024-01-20' '2024-01-27']
# Observation: 246.0
# Observation: 279.0
# Observation: 214.0
# Observation: 171.0
#
# WIS: [ 149.9   308.78  645.32 1076.52]
# Target Dates: ['2024-01-13' '2024-01-20' '2024-01-27' '2024-02-03']
# Observation: 279.0
# Observation: 214.0
# Observation: 171.0
# Observation: 182.0
#
# WIS: [137.15 372.4  640.72 940.01]
# Target Dates: ['2024-01-20' '2024-01-27' '2024-02-03' '2024-02-10']
# Observation: 214.0
# Observation: 171.0
# Observation: 182.0
# Observation: 202.0
#
# WIS: [228.06 428.43 615.57 849.2 ]
# Target Dates: ['2024-02-03' '2024-02-10' '2024-02-17' '2024-02-24']
# Observation: 182.0
# Observation: 202.0
# Observation: 210.0
# Observation: 192.0
#
# WIS: [ 55.34 111.46 148.05 145.23]
# Target Dates: ['2024-02-10' '2024-02-17' '2024-02-24' '2024-03-02']
# Observation: 202.0
# Observation: 210.0
# Observation: 192.0
# Observation: 203.0
#
# WIS: [ 81.83 120.21 126.98 155.74]
# Target Dates: ['2024-02-17' '2024-02-24' '2024-03-02' '2024-03-09']
# Observation: 210.0
# Observation: 192.0
# Observation: 203.0
# Observation: 210.0
#
# WIS: [ 91.92 100.49 135.91 158.33]
# Target Dates: ['2024-02-24' '2024-03-02' '2024-03-09' '2024-03-16']
# Observation: 192.0
# Observation: 203.0
# Observation: 210.0
# Observation: 204.0
#
# WIS: [30.31 45.97 59.2  64.42]
# Target Dates: ['2024-03-02' '2024-03-09' '2024-03-16' '2024-03-23']
# Observation: 203.0
# Observation: 210.0
# Observation: 204.0
# Observation: 162.0
#
# WIS: [48.16 67.9  75.04 41.94]
# Target Dates: ['2024-03-09' '2024-03-16' '2024-03-23' '2024-03-30']
# Observation: 210.0
# Observation: 204.0
# Observation: 162.0
# Observation: 131.0
#
# WIS: [54.94 61.9  34.68 18.64]
# Target Dates: ['2024-03-16' '2024-03-23' '2024-03-30' '2024-04-06']
# Observation: 204.0
# Observation: 162.0
# Observation: 131.0
# Observation: 145.0
#
# WIS: [19.07  7.   15.58 11.25]
# Target Dates: ['2024-03-23' '2024-03-30' '2024-04-06' '2024-04-13']
# Observation: 162.0
# Observation: 131.0
# Observation: 145.0
# Observation: 92.0
#
# WIS: [ 9.24 21.4  11.41 47.57]
# Target Dates: ['2024-03-30' '2024-04-06' '2024-04-13' '2024-04-20']
# Observation: 131.0
# Observation: 145.0
# Observation: 92.0
# Observation: 68.0
#
# WIS: [25.74 13.41 53.34 71.57]
# Target Dates: ['2024-04-06' '2024-04-13' '2024-04-20' '2024-04-27']
# Observation: 145.0
# Observation: 92.0
# Observation: 68.0
# Observation: 54.0
#
# WIS: [ 7.46 26.25 42.66 54.69]
# Target Dates: ['2023-10-14' '2023-10-21' '2023-10-28' '2023-11-04' '2023-11-11']
# Observation: 4.0
# Observation: 5.0
# Observation: 1.0
# Observation: 1.0
#
# WIS: [2.7  3.44 0.29 0.74]
# Target Dates: ['2023-10-21' '2023-10-28' '2023-11-04' '2023-11-11' '2023-11-18']
# Observation: 5.0
# Observation: 1.0
# Observation: 1.0
# Observation: 3.0
#
# WIS: [3.38 4.38 4.48 3.02]
# Target Dates: ['2023-10-28' '2023-11-04' '2023-11-11' '2023-11-18' '2023-11-25']
# Observation: 1.0
# Observation: 1.0
# Observation: 3.0
# Observation: 7.0
#
# WIS: [0.2  4.38 3.08 0.76]
# Target Dates: ['2023-11-11' '2023-11-18' '2023-11-25' '2023-12-02']
# Observation: 3.0
# Observation: 7.0
# Observation: 12.0
# Observation: 15.0
#
# WIS: [2.43 1.14 2.71 6.41]
# Target Dates: ['2023-11-18' '2023-11-25' '2023-12-02' '2023-12-09']
# Observation: 7.0
# Observation: 12.0
# Observation: 15.0
# Observation: 33.0
#
# WIS: [ 1.91  4.73  5.02 24.21]
# Target Dates: ['2023-11-25' '2023-12-02' '2023-12-09' '2023-12-16']
# Observation: 12.0
# Observation: 15.0
# Observation: 33.0
# Observation: 37.0
#
# WIS: [ 0.7   2.91 19.46 13.35]
# Target Dates: ['2023-12-02' '2023-12-09' '2023-12-16' '2023-12-23']
# Observation: 15.0
# Observation: 33.0
# Observation: 37.0
# Observation: 38.0
#
# WIS: [ 4.65 13.53 12.4   7.5 ]
# Target Dates: ['2023-12-09' '2023-12-16' '2023-12-23' '2023-12-30']
# Observation: 33.0
# Check the quantile marks: either no median defined, or not in symmetric central QTL form.
# Empty DataFrame
# Columns: [reference_date, location, horizon, target, target_end_date, output_type, output_type_id, value]
# Index: []
# []
# []
# Observation: 37.0
# Check the quantile marks: either no median defined, or not in symmetric central QTL form.
# Empty DataFrame
# Columns: [reference_date, location, horizon, target, target_end_date, output_type, output_type_id, value]
# Index: []
# []
# []
# Observation: 38.0
# Check the quantile marks: either no median defined, or not in symmetric central QTL form.
# Empty DataFrame
# Columns: [reference_date, location, horizon, target, target_end_date, output_type, output_type_id, value]
# Index: []
# []
# []
# Observation: 63.0
# Check the quantile marks: either no median defined, or not in symmetric central QTL form.
# Empty DataFrame
# Columns: [reference_date, location, horizon, target, target_end_date, output_type, output_type_id, value]
# Index: []
# []
# []
#
# WIS: [0. 0. 0. 0.]
# Target Dates: ['2023-12-16' '2023-12-23' '2023-12-30' '2024-01-06']
# Observation: 37.0
# Observation: 38.0
# Observation: 63.0
# Observation: 68.0
#
# WIS: [ 4.59 21.76 33.03 74.82]
# Target Dates: ['2023-12-23' '2023-12-30' '2024-01-06' '2024-01-13']
# Observation: 38.0
# Observation: 63.0
# Observation: 68.0
# Observation: 62.0
#
# WIS: [ 21.25  29.63  68.05 150.15]
# Target Dates: ['2023-12-30' '2024-01-06' '2024-01-13' '2024-01-20']
# Observation: 63.0
# Observation: 68.0
# Observation: 62.0
# Observation: 37.0
#
# WIS: [  5.74  19.21  53.84 131.63]
# Target Dates: ['2024-01-06' '2024-01-13' '2024-01-20' '2024-01-27']
# Observation: 68.0
# Observation: 62.0
# Observation: 37.0
# Observation: 53.0
#
# WIS: [ 12.57  38.86  96.67 137.26]
# Target Dates: ['2024-01-13' '2024-01-20' '2024-01-27' '2024-02-03']
# Observation: 62.0
# Observation: 37.0
# Observation: 53.0
# Observation: 44.0
#
# WIS: [ 42.11 105.39 134.58 201.67]
# Target Dates: ['2024-01-20' '2024-01-27' '2024-02-03' '2024-02-10']
# Observation: 37.0
# Observation: 53.0
# Observation: 44.0
# Observation: 36.0
#
# WIS: [ 52.39  61.53 101.15 152.97]
# Target Dates: ['2024-02-03' '2024-02-10' '2024-02-17' '2024-02-24']
# Observation: 44.0
# Observation: 36.0
# Observation: 41.0
# Observation: 28.0
#
# WIS: [19.69 11.28 16.74 19.66]
# Target Dates: ['2024-02-10' '2024-02-17' '2024-02-24' '2024-03-02']
# Observation: 36.0
# Observation: 41.0
# Observation: 28.0
# Observation: 27.0
#
# WIS: [ 5.66 20.89  9.75 14.57]
# Target Dates: ['2024-02-17' '2024-02-24' '2024-03-02' '2024-03-09']
# Observation: 41.0
# Observation: 28.0
# Observation: 27.0
# Observation: 18.0
#
# WIS: [16.63  6.4   5.73  2.44]
# Target Dates: ['2024-02-24' '2024-03-02' '2024-03-09' '2024-03-16']
# Observation: 28.0
# Observation: 27.0
# Observation: 18.0
# Observation: 10.0
#
# WIS: [3.37 1.48 4.24 2.82]
# Target Dates: ['2024-03-02' '2024-03-09' '2024-03-16' '2024-03-23']
# Observation: 27.0
# Observation: 18.0
# Observation: 10.0
# Observation: 11.0
#
# WIS: [2.39 1.89 4.5  2.32]
# Target Dates: ['2024-03-09' '2024-03-16' '2024-03-23' '2024-03-30']
# Observation: 18.0
# Observation: 10.0
# Observation: 11.0
# Observation: 12.0
#
# WIS: [3.15 6.26 3.93 2.01]
# Target Dates: ['2024-03-16' '2024-03-23' '2024-03-30' '2024-04-06']
# Observation: 10.0
# Observation: 11.0
# Observation: 12.0
# Observation: 11.0
#
# WIS: [10.07  4.37  3.55  0.97]
# Target Dates: ['2024-03-23' '2024-03-30' '2024-04-06' '2024-04-13']
# Observation: 11.0
# Observation: 12.0
# Observation: 11.0
# Observation: 6.0
#
# WIS: [1.27 1.33 1.47 0.44]
# Target Dates: ['2024-03-30' '2024-04-06' '2024-04-13' '2024-04-20']
# Observation: 12.0
# Observation: 11.0
# Observation: 6.0
# Observation: 3.0
#
# WIS: [1.52 1.12 2.43 2.1 ]
# Target Dates: ['2024-04-06' '2024-04-13' '2024-04-20' '2024-04-27']
# Observation: 11.0
# Observation: 6.0
# Observation: 3.0
# Observation: 4.0
#
# WIS: [1.82 1.1  0.42 1.82]
# Target Dates: ['2023-10-14' '2023-10-21' '2023-10-28' '2023-11-04' '2023-11-11']
# Observation: 100.0
# Observation: 112.0
# Observation: 151.0
# Observation: 136.0
#
# WIS: [ 6.14  7.13 28.65  8.13]
# Target Dates: ['2023-10-21' '2023-10-28' '2023-11-04' '2023-11-11' '2023-11-18']
# Observation: 112.0
# Observation: 151.0
# Observation: 136.0
# Observation: 137.0
#
# WIS: [ 3.99 16.87  5.22 11.34]
# Target Dates: ['2023-10-28' '2023-11-04' '2023-11-11' '2023-11-18' '2023-11-25']
# Observation: 151.0
# Observation: 136.0
# Observation: 137.0
# Observation: 125.0
#
# WIS: [27.32  6.11  4.99 17.62]
# Target Dates: ['2023-11-11' '2023-11-18' '2023-11-25' '2023-12-02']
# Observation: 137.0
# Observation: 125.0
# Observation: 123.0
# Observation: 106.0
#
# WIS: [11.72 35.08 55.12 95.32]
# Target Dates: ['2023-11-18' '2023-11-25' '2023-12-02' '2023-12-09']
# Observation: 125.0
# Observation: 123.0
# Observation: 106.0
# Observation: 74.0
#
# WIS: [ 20.59  36.78  72.12 127.32]
# Target Dates: ['2023-11-25' '2023-12-02' '2023-12-09' '2023-12-16']
# Observation: 123.0
# Observation: 106.0
# Observation: 74.0
# Observation: 65.0
#
# WIS: [ 36.18  71.27 122.8  153.12]
# Target Dates: ['2023-12-02' '2023-12-09' '2023-12-16' '2023-12-23']
# Observation: 106.0
# Observation: 74.0
# Observation: 65.0
# Observation: 59.0
#
# WIS: [ 53.35 101.83 127.95 151.75]
# Target Dates: ['2023-12-09' '2023-12-16' '2023-12-23' '2023-12-30']
# Observation: 74.0
# Observation: 65.0
# Observation: 59.0
# Observation: 65.0
#
# WIS: [38.85 49.8  55.05 49.2 ]
# Target Dates: ['2023-12-16' '2023-12-23' '2023-12-30' '2024-01-06']
# Observation: 65.0
# Observation: 59.0
# Observation: 65.0
# Observation: 63.0
#
# WIS: [4.84 3.21 3.4  5.39]
# Target Dates: ['2023-12-23' '2023-12-30' '2024-01-06' '2024-01-13']
# Observation: 59.0
# Observation: 65.0
# Observation: 63.0
# Observation: 75.0
#
# WIS: [ 5.34 10.93 16.66 37.2 ]
# Target Dates: ['2023-12-30' '2024-01-06' '2024-01-13' '2024-01-20']
# Observation: 65.0
# Observation: 63.0
# Observation: 75.0
# Observation: 69.0
#
# WIS: [11.75 17.26 34.74 32.74]
# Target Dates: ['2024-01-06' '2024-01-13' '2024-01-20' '2024-01-27']
# Observation: 63.0
# Observation: 75.0
# Observation: 69.0
# Observation: 55.0
#
# WIS: [10.95 29.48 32.91 20.06]
# Target Dates: ['2024-01-13' '2024-01-20' '2024-01-27' '2024-02-03']
# Observation: 75.0
# Observation: 69.0
# Observation: 55.0
# Observation: 42.0
#
# WIS: [28.71 29.65 21.72 12.87]
# Target Dates: ['2024-01-20' '2024-01-27' '2024-02-03' '2024-02-10']
# Observation: 69.0
# Observation: 55.0
# Observation: 42.0
# Observation: 65.0
#
# WIS: [24.41 10.94  5.84 30.47]
# Target Dates: ['2024-02-03' '2024-02-10' '2024-02-17' '2024-02-24']
# Observation: 42.0
# Observation: 65.0
# Observation: 58.0
# Observation: 55.0
#
# WIS: [ 5.26 12.53  8.84  6.73]
# Target Dates: ['2024-02-10' '2024-02-17' '2024-02-24' '2024-03-02']
# Observation: 65.0
# Observation: 58.0
# Observation: 55.0
# Observation: 46.0
#
# WIS: [19.85 14.94 14.29  9.47]
# Target Dates: ['2024-02-17' '2024-02-24' '2024-03-02' '2024-03-09']
# Observation: 58.0
# Observation: 55.0
# Observation: 46.0
# Observation: 49.0
#
# WIS: [4.92 3.96 3.32 3.38]
# Target Dates: ['2024-02-24' '2024-03-02' '2024-03-09' '2024-03-16']
# Observation: 55.0
# Observation: 46.0
# Observation: 49.0
# Observation: 51.0
#
# WIS: [5.48 2.6  5.51 5.22]
# Target Dates: ['2024-03-02' '2024-03-09' '2024-03-16' '2024-03-23']
# Observation: 46.0
# Observation: 49.0
# Observation: 51.0
# Observation: 50.0
#
# WIS: [2.54 2.62 7.83 8.26]
# Target Dates: ['2024-03-09' '2024-03-16' '2024-03-23' '2024-03-30']
# Observation: 49.0
# Observation: 51.0
# Observation: 50.0
# Observation: 53.0
#
# WIS: [ 4.95  3.85  6.95 11.  ]
# Target Dates: ['2024-03-16' '2024-03-23' '2024-03-30' '2024-04-06']
# Observation: 51.0
# Observation: 50.0
# Observation: 53.0
# Observation: 42.0
#
# WIS: [3.44 4.25 8.66 2.35]
# Target Dates: ['2024-03-23' '2024-03-30' '2024-04-06' '2024-04-13']
# Observation: 50.0
# Observation: 53.0
# Observation: 42.0
# Observation: 48.0
#
# WIS: [2.61 3.98 1.9  2.87]
# Target Dates: ['2024-03-30' '2024-04-06' '2024-04-13' '2024-04-20']
# Observation: 53.0
# Observation: 42.0
# Observation: 48.0
# Observation: 37.0
#
# WIS: [3.68 2.34 3.21 2.91]
# Target Dates: ['2024-04-06' '2024-04-13' '2024-04-20' '2024-04-27']
# Observation: 42.0
# Observation: 48.0
# Observation: 37.0
# Observation: 36.0
#
# WIS: [2.42 2.39 3.33 2.32]

# %%
'''Plotting'''
def plot_one_state(state_csv):
    data = pd.read_csv(state_csv)

    data['date'] = pd.to_datetime(data['date'])
    state_name = data['state_abbrev'][1]

    palette = sns.color_palette("colorblind")  

    plt.figure(figsize=(10, 4))
    sns.lineplot(x='date', y='1wk_WIS', data=data, label='1-Week WIS', color=palette[0], linestyle='-')
    sns.lineplot(x='date', y='2wk_WIS', data=data, label='2-Week WIS', color=palette[1], linestyle='--')
    sns.lineplot(x='date', y='3wk_WIS', data=data, label='3-Week WIS', color=palette[2], linestyle='-.')
    sns.lineplot(x='date', y='4wk_WIS', data=data, label='4-Week WIS', color=palette[4], linestyle=':')

    plt.title('WIS Scores Over Time :: MCMC Forecast :: ' + state_name)
    plt.xlabel('Date')
    plt.ylabel('WIS')
    plt.legend(title='Forecast Horizon')
    plt.grid(True)
    plt.show()


plot_one_state('./mcmc_accuracy_results/AZ.csv')

# %%
def plot_average_of_all_states(data_folder_path):
    # Directory containing all the CSV files

    # List to hold data from each state
    data_list = []
    wis_columns = ['1wk_WIS', '2wk_WIS', '3wk_WIS', '4wk_WIS']

    # Read each CSV file in the directory
    for filename in listdir(data_folder_path):
        if filename.endswith('.csv'):
            # Load the data
            file_path = join(data_folder_path, filename)
            data = pd.read_csv(file_path)

            # Convert 'date' column to datetime format
            data['date'] = pd.to_datetime(data['date'])

            print(data[wis_columns])

            for col in wis_columns:
                data[col] = pd.to_numeric(data[col], errors='coerce')

            # Check if any row has all zeros in WIS columns
            # if so, don't use it. 
            if not (data[wis_columns] == 0).all(axis=1).any():
                data_list.append(data)

    # Concatenate all dataframes
    combined_data = pd.concat(data_list)

    # Group by date and calculate the mean for each WIS
    average_data = combined_data.groupby('date')[wis_columns].mean().reset_index()
    print(average_data)

    # Plotting the averaged WIS scores over time
    plt.figure(figsize=(12, 6))
    sns.lineplot(x='date', y='1wk_WIS', data=average_data, label='Average 1-Week WIS', color='blue', linestyle='-', linewidth=2.5)
    sns.lineplot(x='date', y='2wk_WIS', data=average_data, label='Average 2-Week WIS', color='red', linestyle='--', linewidth=2.5)
    sns.lineplot(x='date', y='3wk_WIS', data=average_data, label='Average 3-Week WIS', color='green', linestyle='-.', linewidth=2.5)
    sns.lineplot(x='date', y='4wk_WIS', data=average_data, label='Average 4-Week WIS', color='purple', linestyle=':', linewidth=2.5)

    plt.title('Average WIS Scores Over Time Across States :: MCMC Forecast')
    plt.xlabel('Date')
    plt.ylabel('Average WIS')
    plt.legend(title='Forecast Horizon')
    plt.grid(True)
    plt.show()

plot_average_of_all_states('./mcmc_accuracy_results/')
# Out:
#     1wk_WIS  2wk_WIS  3wk_WIS  4wk_WIS
# 0     13.96    20.47    26.59    32.46
# 1     11.13     7.98    17.58    64.31
# 2     12.13    18.74    56.58   124.31
# 3     28.20    79.27    98.32   141.61
# 4     88.20   110.27   154.32   232.61
# 5     34.62    51.55    89.54   158.12
# 6     14.08    23.61    50.70   191.40
# 7     36.13    81.89   119.06   333.32
# 8     22.45    40.76    58.83   261.04
# 9     77.31    55.19    95.74   482.76
# 10   190.05   532.57  1120.86  1872.30
# 11   545.17  1138.66  1888.50  2752.71
# 12   669.00  1275.98  2005.39  2830.31
# 13   695.54  1198.30  1764.34  2431.39
# 14    17.94    89.52    94.83   102.97
# 15    29.82    31.02    39.63    21.69
# 16    20.47    11.22    21.07    16.33
# 17    24.63    37.07    29.43    59.78
# 18    29.62    20.65    47.75    30.57
# 19     8.17    28.78    17.44    20.23
# 20    38.50    21.62    24.63    39.40
# 21    16.47    20.90    34.37    31.74
# 22     8.52    22.55    21.67    20.03
# 23    27.35    26.82    22.13    46.69
#     1wk_WIS  2wk_WIS  3wk_WIS  4wk_WIS
# 0      1.36     8.96    12.76    12.07
# 1      7.97     7.05     5.91    11.62
# 2     11.62     6.39    15.13    33.54
# 3      9.73    27.92    17.22    27.82
# 4     29.66    21.84    26.24    34.09
# 5      7.04    14.10    15.45    43.41
# 6      9.57     7.18    32.32   100.84
# 7     16.41    10.89    13.41    14.08
# 8      6.75    16.52    10.69    21.56
# 9     39.69    37.27    73.34     7.57
# 10    16.57    13.97    98.11   246.31
# 11    20.64   138.11   304.85   498.17
# 12   147.54   314.69   510.46   706.02
# 13   185.34   332.62   486.25   647.48
# 14    10.21     9.62    14.93    12.60
# 15    18.90    28.18    32.36    37.05
# 16    20.43    27.47    29.85    39.24
# 17    22.46    23.79    26.10    38.11
# 18    17.36    19.94    33.24    39.28
# 19    12.18    22.32    25.24    38.28
# 20    21.70    15.72    28.46    15.61
# 21    12.36    18.98     9.55     5.76
# 22    11.88     6.68     3.56     2.89
# 23     4.15     2.76     4.05     3.06
#     1wk_WIS  2wk_WIS  3wk_WIS  4wk_WIS
# 0