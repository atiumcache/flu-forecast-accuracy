# %%
from mcmc_plotting import *

# %%
"""
Running the forecast accuracy score calculations for all states.
Exports all scores to csv. 
"""

# %run main.py
# Out:
# Number of Locations: 52
# Check the quantile marks: either no median defined, or not in symmetric central QTL form.
# An error occured. Output may include a row of 0's.
# Check the MI data file.
#
# Check the quantile marks: either no median defined, or not in symmetric central QTL form.
# An error occured. Output may include a row of 0's.
# Check the MI data file.
#
# Check the quantile marks: either no median defined, or not in symmetric central QTL form.
# An error occured. Output may include a row of 0's.
# Check the MI data file.
#
# Check the quantile marks: either no median defined, or not in symmetric central QTL form.
# An error occured. Output may include a row of 0's.
# Check the MI data file.
#
# Check the quantile marks: either no median defined, or not in symmetric central QTL form.
# An error occured. Output may include a row of 0's.
# Check the WY data file.
#
# Check the quantile marks: either no median defined, or not in symmetric central QTL form.
# ...

# %%
plot_one_state('./mcmc_accuracy_results/AZ.csv')

# %%
plot_average_of_all_states('./mcmc_accuracy_results/')
